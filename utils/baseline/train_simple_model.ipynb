# %% [markdown]
# This notebook creates a very simple model for generating outfits. This is sligth better than a random model. It computes the most popular category combinations in the outfits dataset and sort the candidate items, by this category combination pupularity.
#
# This script takes less than 5 minutes to run

# %% [markdown]
# # Train - Computation of the category combinations

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2022-05-22 21:08:00.057456

# %%
import pandas as pd

full_outfits = pd.read_parquet("../data/manual_outfits.parquet")
full_outfits.head()
# Out:
#                                             products  outfit_id
# 0  [15360881, 15379678, 15781925, 16204075, 16260...          0
# 1  [13893589, 13893721, 15426616, 16035469, 17173...          1
# 2  [13508028, 14161732, 16160567, 17484491, 17503...          2
# 3  [16127776, 16756133, 17040752, 18203427, 18205...          3
# 4                     [14480467, 15487690, 17257765]          4

# %%
items_metadata = pd.read_parquet("../data/products.parquet")
items_metadata = items_metadata[["product_id", "product_category"]]
items_metadata.set_index("product_id", inplace=True)
items_metadata.head()
# Out:
#                product_category
# product_id
# 17073270               Knitwear
# 17674562               Knitwear
# 17678603               Knitwear
# 17179699               Knitwear
# 15907453    Sweaters & Knitwear

# %%
outfits_category = full_outfits.explode(column="products")
outfits_category = outfits_category.merge(
    items_metadata,
    left_on="products",
    right_on=items_metadata.index,
    how="inner"
)
outfits_category.rename(columns={"product_category": "categories"}, inplace=True)
outfits_category.head()
# Out:
#    products  outfit_id categories
# 0  15360881          0   Trainers
# 1  15360881        716   Trainers
# 2  15360881        977   Trainers
# 3  15360881       1069   Trainers
# 4  15360881       1186   Trainers

# %%
outfits_category = outfits_category.groupby("outfit_id").agg({"categories": list, "products": list})
outfits_category.reset_index(inplace=True)

outfits_category["categories_sorted"] = outfits_category.apply(lambda row: frozenset(row["categories"]), axis=1)
outfits_category.head()
# Out:
#    outfit_id                                         categories  \
# 0          0  [Trainers, Shirts, Jackets, Clutch Bags, Trous...
# 1          1  [Necklaces, Necklaces, Necklaces, Earrings, Sa...
# 2          2  [Earrings, Trainers, Trousers, Tops, Satchels ...
# 3          3        [Denim, Earrings, Pumps, All in One, Coats]
# 4          4     [Trainers, Shoulder Bags, Sweaters & Knitwear]
#
#                                             products  \
# 0  [15360881, 15379678, 15781925, 16204075, 16260...
# 1  [13893589, 13893721, 15426616, 16035469, 17173...
# 2  [13508028, 14161732, 16160567, 17484491, 17503...
# 3  [16127776, 16756133, 17040752, 18203427, 18205...
# 4                     [14480467, 15487690, 17257765]
#
#                                    categories_sorted
# 0  (Shirts, Clutch Bags, Trousers, Jackets, Train...
# 1            (Necklaces, Sandals, Earrings, Jackets)
# 2  (Tops, Earrings, Trousers, Satchels & Cross Bo...
# 3        (Coats, Denim, All in One, Earrings, Pumps)
# 4     (Shoulder Bags, Trainers, Sweaters & Knitwear)

# %%
from collections import Counter, defaultdict

categories_sets = Counter(outfits_category.categories_sorted.values)
toy_model = {
    "items_metadata": items_metadata,
    "categories_sets": categories_sets
}
toy_model
# Out:
# {'items_metadata':                product_category
#  product_id
#  17073270               Knitwear
#  17674562               Knitwear
#  17678603               Knitwear
#  17179699               Knitwear
#  15907453    Sweaters & Knitwear
#  ...                         ...
#  18020113                  Denim
#  18151251                  Denim
#  18161372                  Denim
#  18164968                  Denim
#  18250540                  Denim
#
#  [398670 rows x 1 columns],
#  'categories_sets': Counter({frozenset({'Clutch Bags',
#                      'Jackets',
#                      'Shirts',
#                      'Trainers',
#                      'Trousers'}): 32,
#           frozenset({'Earrings', 'Jackets', 'Necklaces', 'Sandals'}): 1,
#           frozenset({'Earrings',
#                      'Satchels & Cross Body Bags',
#                      'Tops',
#                      'Trainers',
#                      'Trousers'}): 79,
#           frozenset({'All in One', 'Coats', 'Denim', 'Earrings', 'Pumps'}): 1,
#           frozenset({'Shoulder Bags', 'Sweaters & Knitwear', 'Trainers'}): 35,
#           frozenset({'Derby Shoes',
#                      'Jackets',
#                      'Jumpsuits',
#                      'Sweaters & Knitwear',
#                      'Tote Bags'}): 1,
#           frozenset({'Bucket Bags',
#                      'Earrings',
#                      'Knitwear',
#                      'Trainers',
#                      'Trousers'}): 18,
#           frozenset({'Denim',
#                      'Shoulder Bags',
#                      'Sweaters & Knitwear',
#                      'Trainers'}): 135,
#           frozenset({'Denim',
#                      'Earrings',
#                      'Sandals',
#                      'Shoulder Bags',
#                      'Tops'}): 402,
#           frozenset({'Boots',
#                      'Jackets',
#                      'Sweaters & Knitwear',
#                      'Trousers'}): 276,
#           frozenset({'Earrings',
#                      'Sandals',
#                      'Skirts',
#                      'Sunglasses',
#                      'Tops'}): 22,
#           frozenset({'Denim', 'Sandals', 'Shoulder Bags', 'Tops'}): 229,
#           frozenset({'Boots', 'Dresses', 'Shoulder Bags'}): 257,
#           frozenset({'Hats',
#                      'Rings',
#                      'Sweaters & Knitwear',
#                      'Tote Bags',
#                      'Trainers',
#                      'Trousers'}): 10,
#           frozenset({'Necklaces',
#                      'Polo Shirts',
#                      'Rings',
#                      'Shoulder Bags',
#                      'Sunglasses',
#                      'Trainers',
#                      'Trousers'}): 1,
#           frozenset({'Coats',
#                      'Messenger Bags',
#                      'Necklaces',
#                      'Shorts',
#                      'Sunglasses',
#                      'T-Shirts & Vests',
#                      'Trainers'}): 1,
#           frozenset({'Knitwear', 'Tote Bags', 'Trousers'}): 82,
#           frozenset({'Derby Shoes',
#                      'Hats',
#                      'Rings',
#                      'Shorts',
#                      'Shoulder Bags',
#                      'T-Shirts & Vests'}): 2,
#           frozenset({'Earrings',
#                      'Mules',
#                      'Tops',
#                      'Tote Bags',
#                      'Trousers'}): 205,
#           frozenset({'Earrings', 'Jackets', 'Knitwear', 'Trousers'}): 18,
#           frozenset({'Belt Bags',
#                      'Boots',
#                      'Earrings',
#                      'Jackets',
#                      'Trousers'}): 1,
#           frozenset({'T-Shirts & Vests', 'Tote Bags', 'Trousers'}): 43,
#           frozenset({'Earrings',
#                      'Knitwear',
#                      'Mules',
#                      'Necklaces',
#                      'Rings',
#                      'Shoulder Bags',
#                      'Skirts'}): 3,
#           frozenset({'Earrings',
#                      'Rings',
#                      'Sandals',
#                      'Satchels & Cross Body Bags',
#                      'Tops',
#                      'Trousers'}): 39,
#           frozenset({'Messenger Bags', 'Tops', 'Trousers'}): 5,
#           frozenset({'Boots', 'Shoulder Bags', 'Tops', 'Trousers'}): 117,
#           frozenset({'Boots',
#                      'Clutch Bags',
#                      'Denim',
#                      'Earrings',
#                      'Jackets',
#                      'Tops'}): 26,
#           frozenset({'Boots',
#                      'Earrings',
#                      'Hats',
#                      'Jackets',
#                      'Knitwear',
#                      'Tote Bags',
#                      'Trousers'}): 1,
#           frozenset({'Knitwear', 'Mini Bags', 'Sandals'}): 36,
#           frozenset({'Boots',
#                      'Satchels & Cross Body Bags',
#                      'Skirts',
#                      'Tops'}): 64,
#           frozenset({'Clutch Bags',
#                      'Earrings',
#                      'Knitwear',
#                      'Mules',
#                      'Necklaces'}): 2,
#           frozenset({'Boots', 'Denim', 'Earrings', 'Jackets'}): 15,
#           frozenset({'Sandals', 'Shirts', 'Tote Bags', 'Trousers'}): 63,
#           frozenset({'Backpacks', 'Sweaters & Knitwear', 'Trainers'}): 39,
#           frozenset({'Denim',
#                      'Earrings',
#                      'Jackets',
#                      'Sandals',
#                      'Shoulder Bags'}): 27,
#           frozenset({'Dresses',
#                      'Earrings',
#                      'Rings',
#                      'Sandals',
#                      'Tote Bags'}): 191,
#           frozenset({'Coats',
#                      'Earrings',
#                      'Pumps',
#                      'Rings',
#                      'Skirts',
#                      'Tops',
#                      'Tote Bags'}): 1,
#           frozenset({'Hats',
#                      'Messenger Bags',
#                      'Sunglasses',
#                      'Trainers',
#                      'Trousers'}): 1,
#           frozenset({'Earrings',
#                      'Knitwear',
#                      'Loafers',
#                      'Shorts',
#                      'Shoulder Bags'}): 28,
#           frozenset({'Clutch Bags', 'Earrings', 'Loafers', 'Tops'}): 3,
#           frozenset({'Necklaces',
#                      'Sandals',
#                      'Shorts',
#                      'Sunglasses',
#                      'Tops',
#                      'Tote Bags'}): 12,
#           frozenset({'Belts', 'Knitwear', 'Trousers', 'Watches'}): 2,
#           frozenset({'Backpacks',
#                      'Denim',
#                      'Messenger Bags',
#                      'Shirts',
#                      'Sweaters & Knitwear',
#                      'Trainers'}): 2,
#           frozenset({'Earrings',
#                      'Flip Flops & Slides',
#                      'Knitwear',
#                      'Tops',
#                      'Trousers'}): 4,
#           frozenset({'Boots',
#                      'Clutch Bags',
#                      'Earrings',
#                      'Knitwear',
#                      'Skirts'}): 109,
#           frozenset({'Clutch Bags', 'Denim', 'Jackets', 'Mules', 'Tops'}): 2,
#           frozenset({'Boots',
#                      'Rings',
#                      'Shirts',
#                      'Shorts',
#                      'Shoulder Bags',
#                      'Sweaters & Knitwear'}): 3,
#           frozenset({'Jackets',
#                      'Messenger Bags',
#                      'Sunglasses',
#                      'Sweaters & Knitwear',
#                      'Trainers',
#                      'Trousers'}): 9,
#           frozenset({'Shorts', 'Tops', 'Trainers'}): 172,
#           frozenset({'Denim', 'Shoulder Bags', 'Tops'}): 75,
#           frozenset({'Boots', 'Earrings', 'Skirts', 'Tops', 'Tote Bags'}): 151,
#           frozenset({'Clutch Bags', 'Derby Shoes', 'Jackets', 'Shorts'}): 1,
#           frozenset({'Denim',
#                      'Earrings',
#                      'Jackets',
#                      'Sandals',
#                      'Tops',
#                      'Tote Bags'}): 64,
#           frozenset({'Clutch Bags',
#                      'Earrings',
#                      'Sunglasses',
#                      'Tops',
#                      'Trainers',
#                      'Trousers'}): 7,
#           frozenset({'Backpacks',
#                      'Coats',
#                      'Shirts',
#                      'Sweaters & Knitwear',
#                      'Trainers',
#                      'Trousers',
#                      'Wallets & Cardholders'}): 1,
#           frozenset({'Loafers',
#                      'Luggage & Holdalls',
#                      'Necklaces',
#                      'Sweaters & Knitwear'}): 2,
#           frozenset({'Boots',
#                      'Hats',
#                      'Messenger Bags',
#                      'Rings',
#                      'Sweaters & Knitwear'}): 1,
#           frozenset({'Dresses', 'Sandals', 'Tote Bags'}): 594,
#           frozenset({'Polo Shirts', 'Shorts', 'Tote Bags', 'Trainers'}): 89,
#           frozenset({'Belts',
#                      'Boots',
#                      'Denim',
#                      'Jackets',
#                      'Shirts',
#                      'Sweaters & Knitwear'}): 4,
#           frozenset({'Backpacks',
#                      'Sandals',
#                      'Socks',
#                      'T-Shirts & Vests',
#                      'Trousers'}): 2,
#           frozenset({'Boots',
#                      'Clutch Bags',
#                      'Earrings',
#                      'Shorts',
#                      'Tops'}): 31,
#           frozenset({'Belt Bags',
#                      'Boots',
#                      'Coats',
#                      'Denim',
#                      'Rings',
#                      'Sweaters & Knitwear'}): 3,
#           frozenset({'Boots',
#                      'Earrings',
#                      'Mini Bags',
#                      'Rings',
#                      'Tops',
#                      'Trousers'}): 24,
#           frozenset({'Boots',
#                      'Shirts',
#                      'Sweaters & Knitwear',
#                      'Tote Bags',
#                      'Trousers'}): 23,
#           frozenset({'Knitwear', 'Mini Bags', 'Sunglasses', 'Trainers'}): 3,
#           frozenset({'Boots',
#                      'Jackets',
#                      'Necklaces',
#                      'T-Shirts & Vests',
#                      'Trousers'}): 23,
#           frozenset({'Shorts',
#                      'Sweaters & Knitwear',
#                      'Tote Bags',
#                      'Trainers'}): 301,
#           frozenset({'Denim', 'Jackets', 'T-Shirts & Vests', 'Trainers'}): 355,
#           frozenset({'Jackets',
#                      'Shirts',
#                      'Sunglasses',
#                      'T-Shirts & Vests',
#                      'Ties & Bow Ties',
#                      'Tote Bags',
#                      'Trousers'}): 1,
#           frozenset({'Boots',
#                      'Denim',
#                      'Sweaters & Knitwear',
#                      'T-Shirts & Vests',
#                      'Tote Bags'}): 41,
#           frozenset({'Boots', 'Dresses', 'Earrings', 'Shoulder Bags'}): 404,
#           frozenset({'Denim', 'Tops', 'Trainers'}): 142,
#           frozenset({'T-Shirts & Vests',
#                      'Tote Bags',
#                      'Trainers',
#                      'Trousers'}): 553,
#           frozenset({'Backpacks', 'Dresses', 'Earrings', 'Trainers'}): 13,
#           frozenset({'Pumps', 'Shoulder Bags', 'Skirts', 'Tops'}): 27,
#           frozenset({'Luggage & Holdalls',
#                      'Rings',
#                      'Sweaters & Knitwear',
#                      'Trainers',
#                      'Trousers'}): 2,
#           frozenset({'Belt Bags',
#                      'Face Masks',
#                      'Hats',
#                      'Jackets',
#                      'Phone, Computer & Gadgets',
#                      'Rings',
#                      'Sunglasses',
#                      'T-Shirts & Vests',
#                      'Trainers',
#                      'Trousers'}): 1,
#           frozenset({'Boots',
#                      'Earrings',
#                      'Hats',
#                      'Shorts',
#                      'Tops',
#                      'Tote Bags'}): 8,
#           frozenset({'T-Shirts & Vests', 'Trainers', 'Trousers'}): 920,
#           frozenset({'Hats',
#                      'Jackets',
#                      'Messenger Bags',
#                      'Sandals',
#                      'Trousers'}): 1,
#           frozenset({'Boots', 'Dresses', 'Knitwear', 'Shoulder Bags'}): 14,
#           frozenset({'Jackets', 'Sandals', 'Trousers'}): 67,
#           frozenset({'Jackets', 'Shirts', 'Trainers', 'Trousers'}): 176,
#           frozenset({'Bucket Bags',
#                      'Earrings',
#                      'Knitwear',
#                      'Rings',
#                      'Trousers'}): 2,
#           frozenset({'Backpacks',
#                      'Shirts',
#                      'T-Shirts & Vests',
#                      'Trainers'}): 5,
#           frozenset({'Belts',
#                      'Boots',
#                      'Denim',
#                      'Jackets',
#                      'Shirts',
#                      'Sunglasses'}): 3,
#           frozenset({'Belt Bags',
#                      'Hats',
#                      'Rings',
#                      'T-Shirts & Vests',
#                      'Trainers',
#                      'Trousers'}): 4,
#           frozenset({'Denim',
#                      'Rings',
#                      'Shoulder Bags',
#                      'Sunglasses',
#                      'Sweaters & Knitwear',
#                      'T-Shirts & Vests',
#                      'Trainers'}): 1,
#           frozenset({'Rings',
#                      'Shirts',
#                      'Shoulder Bags',
#                      'Sunglasses',
#                      'Trousers'}): 1,
#           frozenset({'Bodies',
#                      'Boots',
#                      'Coats',
#                      'Denim',
#                      'Earrings',
#                      'Shoulder Bags'}): 2,
#           frozenset({'Boots',
#                      'Clutch Bags',
#                      'Earrings',
#                      'Tops',
#                      'Trousers'}): 114,
#           frozenset({'Belts', 'Boots', 'Shorts', 'Shoulder Bags', 'Tops'}): 5,
#           frozenset({'Boots', 'Sunglasses', 'Tops', 'Tote Bags'}): 4,
#           frozenset({'Dresses', 'Knitwear', 'Scarves'}): 1,
#           frozenset({'Denim',
#                      'Messenger Bags',
#                      'Shirts',
#                      'T-Shirts & Vests',
#                      'Trainers'}): 42,
#           frozenset({'Hats', 'Rings', 'Tote Bags', 'Trainers', 'Trousers'}): 1,
#           frozenset({'Derby Shoes',
#                      'Jackets',
#                      'T-Shirts & Vests',
#                      'Tote Bags',
#                      'Trousers'}): 33,
#           frozenset({'Boots',
#                      'Earrings',
#                      'Jackets',
#                      'Knitwear',
#                      'Rings',
#                      'Skirts'}): 5,
#           frozenset({'Earrings', 'Hats', 'Sandals', 'Tops'}): 3,
#           frozenset({'Jackets',
#                      'Rings',
#                      'Sweaters & Knitwear',
#                      'T-Shirts & Vests',
#                      'Trainers',
#                      'Trousers'}): 7,
#           frozenset({'Boots',
#                      'Denim',
#                      'Necklaces',
#                      'Shoulder Bags',
#                      'Sweaters & Knitwear'}): 7,
#           frozenset({'Earrings',
#                      'Hats',
#                      'Sandals',
#                      'Shoulder Bags',
#                      'Tops',
#                      'Trousers'}): 28,
#           frozenset({'Belt Bags',
#                      'Boots',
#                      'Coats',
#                      'Hats',
#                      'Sweaters & Knitwear',
#                      'Trousers'}): 1,
#           frozenset({'Earrings',
#                      'Jackets',
#                      'Mini Bags',
#                      'Tops',
#                      'Trainers',
#                      'Trousers'}): 15,
#           frozenset({'Bracelets',
#                      'Bucket Bags',
#                      'Earrings',
#                      'Sandals',
#                      'Tops',
#                      'Trousers'}): 17,
#           frozenset({'Loafers',
#                      'Messenger Bags',
#                      'Shirts',
#                      'Sunglasses',
#                      'Trousers'}): 9,
#           frozenset({'Derby Shoes',
#                      'Rings',
#                      'Shorts',
#                      'T-Shirts & Vests',
#                      'Tote Bags'}): 4,
#           frozenset({'Bracelets',
#                      'Dresses',
#                      'Earrings',
#                      'Mini Bags',
#                      'Mules',
#                      'Shoulder Bags'}): 1,
#           frozenset({'Boots',
#                      'Earrings',
#                      'Knitwear',
#                      'Rings',
#                      'Shoulder Bags',
#                      'Tops',
#                      'Trousers'}): 9,
#           frozenset({'Dresses', 'Jackets', 'Sunglasses'}): 3,
#           frozenset({'Denim',
#                      'Earrings',
#                      'Shoulder Bags',
#                      'Tops',
#                      'Tote Bags',
#                      'Trainers'}): 2,
#           frozenset({'Boots',
#                      'Shorts',
#                      'Sunglasses',
#                      'Sweaters & Knitwear',
#                      'T-Shirts & Vests',
#                      'Tote Bags'}): 2,
#           frozenset({'Bodies',
#                      'Boots',
#                      'Earrings',
#                      'Tote Bags',
#                      'Trousers'}): 1,
#           frozenset({'Earrings',
#                      'Necklaces',
#                      'Sandals',
#                      'Shorts',
#                      'Tops',
#                      'Tote Bags'}): 20,
#           frozenset({'Boots',
#                      'Coats',
#                      'Earrings',
#                      'Mini Bags',
#                      'Tailoring',
#                      'Tops'}): 1,
#           frozenset({'Hats',
#                      'Rings',
#                      'Sandals',
#                      'T-Shirts & Vests',
#                      'Tote Bags',
#                      'Trousers'}): 3,
#           frozenset({'Boots',
#                      'T-Shirts & Vests',
#                      'Tote Bags',
#                      'Trousers'}): 140,
#           frozenset({'Earrings',
#                      'Sandals',
#                      'Shirts',
#                      'Tote Bags',
#                      'Trousers',
#                      'Wallets & Cardholders'}): 1,
#           frozenset({'Dresses',
#                      'Earrings',
#                      'Fine Bracelets',
#                      'Sandals',
#                      'Tote Bags'}): 14,
#           frozenset({'Boots',
#                      'Dresses',
#                      'Earrings',
#                      'Hair Accessories',
#                      'Shoulder Bags'}): 12,
#           frozenset({'Jackets', 'Monk Shoes', 'Shirts', 'Trousers'}): 7,
#           frozenset({'Earrings',
#                      'Glasses & Frames',
#                      'Mini Bags',
#                      'Sandals',
#                      'Sunglasses',
#                      'Tops',
#                      'Trousers'}): 7,
#           frozenset({'Jackets', 'Loafers', 'Trousers'}): 29,
#           frozenset({'Bracelets',
#                      'Denim',
#                      'Hats',
#                      'Messenger Bags',
#                      'Necklaces',
#                      'Performance Tops',
#                      'Rings',
#                      'Sweaters & Knitwear',
#                      'Trainers'}): 1,
#           frozenset({'Boots', 'Skirts', 'Tops'}): 180,
#           frozenset({'Clutch Bags',
#                      'Jackets',
#                      'Loafers',
#                      'Necklaces',
#                      'Shirts',
#                      'Trousers'}): 6,
#           frozenset({'Earrings',
#                      'Pumps',
#                      'Rings',
#                      'Satchels & Cross Body Bags',
#                      'Tops',
#                      'Trousers'}): 9,
#           frozenset({'Denim',
#                      'Hats',
#                      'Jackets',
#                      'Shoulder Bags',
#                      'Slippers',
#                      'T-Shirts & Vests'}): 1,
#           frozenset({'Hats',
#                      'Shorts',
#                      'Socks',
#                      'Sweaters & Knitwear',
#                      'Trainers'}): 3,
#           frozenset({'Knitwear', 'Sandals', 'Scarves', 'Trousers'}): 2,
#           frozenset({'Backpacks',
#                      'T-Shirts & Vests',
#                      'Trainers',
#                      'Trousers'}): 268,
#           frozenset({'Denim', 'Earrings', 'Tote Bags', 'Trainers'}): 3,
#           frozenset({'Denim', 'Jackets', 'Shirts', 'Trainers'}): 52,
#           frozenset({'Coats',
#                      'Pumps',
#                      'Shoulder Bags',
#                      'Tops',
#                      'Trousers'}): 23,
#           frozenset({'Sandals', 'Shoulder Bags', 'Skirts', 'Tops'}): 190,
#           frozenset({'Shorts',
#                      'T-Shirts & Vests',
#                      'Tote Bags',
#                      'Trainers'}): 477,
#           frozenset({'Denim', 'Tops'}): 25,
#           frozenset({'Boots',
#                      'Earrings',
#                      'Hats',
#                      'Shoulder Bags',
#                      'Tops'}): 26,
#           frozenset({'Dresses', 'Earrings', 'Mules', 'Shoulder Bags'}): 305,
#           frozenset({'Clutch Bags', 'Mules', 'Skirts'}): 3,
#           frozenset({'Boots',
#                      'Earrings',
#                      'Knitwear',
#                      'Mini Bags',
#                      'Sunglasses'}): 18,
#           frozenset({'Dresses', 'Mules', 'Satchels & Cross Body Bags'}): 67,
#           frozenset({'Boots',
#                      'Denim',
#                      'Sweaters & Knitwear',
#                      'T-Shirts & Vests'}): 72,
#           frozenset({'Coats',
#                      'Shirts',
#                      'T-Shirts & Vests',
#                      'Trainers',
#                      'Trousers'}): 9,
#           frozenset({'Boots',
#                      'Camisoles & Corsets',
#                      'Clutch Bags',
#                      'Earrings',
#                      'Skirts',
#                      'Tops'}): 1,
#           frozenset({'Boots',
#                      'Earrings',
#                      'Necklaces',
#                      'Phone, Computer & Gadgets',
#                      'Sunglasses',
#                      'Tops',
#                      'Trousers'}): 2,
#           frozenset({'Belt Bags', 'Trainers', 'Trousers'}): 17,
#           frozenset({'Earrings', 'Sandals', 'Tops', 'Trousers'}): 565,
#           frozenset({'Rings',
#                      'Sandals',
#                      'Shorts',
#                      'Sunglasses',
#                      'T-Shirts & Vests',
#                      'Tote Bags'}): 1,
#           frozenset({'Boots', 'Denim', 'Jackets', 'Sweaters & Knitwear'}): 188,
#           frozenset({'Earrings',
#                      'Mini Bags',
#                      'Sandals',
#                      'Shorts',
#                      'Sunglasses',
#                      'Tops'}): 26,
#           frozenset({'Messenger Bags',
#                      'Shorts',
#                      'Socks',
#                      'Sunglasses',
#                      'Sweaters & Knitwear',
#                      'T-Shirts & Vests',
#                      'Trainers'}): 1,
#           frozenset({'Dresses', 'Earrings', 'Satchels & Cross Body Bags'}): 78,
#           frozenset({'Earrings',
#                      'Sandals',
#                      'Satchels & Cross Body Bags',
#                      'Skirts',
#                      'Tops'}): 185,
#           frozenset({'Shoulder Bags',
#                      'Sunglasses',
#                      'T-Shirts & Vests',
#                      'Trainers',
#                      'Trousers'}): 20,
#           frozenset({'Jackets', 'Scarves', 'Shirts'}): 13,
#           frozenset({'Jackets', 'Shoulder Bags', 'Tops', 'Trousers'}): 40,
#           frozenset({'Messenger Bags',
#                      'Performance Footwear',
#                      'T-Shirts & Vests'}): 2,
#           frozenset({'Boots',
#                      'Jackets',
#                      'Messenger Bags',
#                      'Necklaces',
#                      'Shirts',
#                      'Sunglasses',
#                      'Trousers'}): 4,
#           frozenset({'All in One',
#                      'Belts',
#                      'Boots',
#                      'Necklaces',
#                      'Tote Bags'}): 1,
#           frozenset({'Shorts',
#                      'Sunglasses',
#                      'Sweaters & Knitwear',
#                      'Trainers'}): 42,
#           frozenset({'Jackets', 'Trainers', 'Trousers'}): 201,
#           frozenset({'Shorts', 'T-Shirts & Vests', 'Trainers'}): 941,
#           frozenset({'Bracelets',
#                      'Shorts',
#                      'T-Shirts & Vests',
#                      'Trainers'}): 95,
#           frozenset({'Clutch Bags',
#                      'Earrings',
#                      'Glasses & Frames',
#                      'Loafers',
#                      'Shorts',
#                      'Sunglasses',
#                      'Tops'}): 1,
#           frozenset({'Bracelets',
#                      'Denim',
#                      'Earrings',
#                      'Mules',
#                      'Satchels & Cross Body Bags',
#                      'Tops'}): 7,
#           frozenset({'Backpacks',
#                      'Boots',
#                      'Sunglasses',
#                      'Sweaters & Knitwear',
#                      'T-Shirts & Vests',
#                      'Trousers'}): 3,
#           frozenset({'Earrings',
#                      'Knitwear',
#                      'Pumps',
#                      'Shoulder Bags',
#                      'Trousers'}): 41,
#           frozenset({'Boots',
#                      'Coats',
#                      'Earrings',
#                      'Knitwear',
#                      'Trousers'}): 81,
#           frozenset({'Boots',
#                      'Denim',
#                      'Necklaces',
#                      'Sweaters & Knitwear',
#                      'T-Shirts & Vests',
#                      'Tote Bags'}): 9,
#           frozenset({'Boots',
#                      'Shoulder Bags',
#                      'Sunglasses',
#                      'Sweaters & Knitwear'}): 9,
#           frozenset({'Luggage & Holdalls',
#                      'Shorts',
#                      'Sunglasses',
#                      'T-Shirts & Vests',
#                      'Trainers'}): 8,
#           frozenset({'Dresses',
#                      'Earrings',
#                      'Sandals',
#                      'Shoulder Bags',
#                      'Sunglasses'}): 337,
#           frozenset({'Jackets',
#                      'T-Shirts & Vests',
#                      'Trainers',
#                      'Trousers'}): 1022,
#           frozenset({'Bucket Bags',
#                      'Earrings',
#                      'Skirts',
#                      'Sunglasses',
#                      'Tops'}): 8,
#           frozenset({'Jackets',
#                      'Sandals',
#                      'Skirts',
#                      'Tops',
#                      'Tote Bags',
#                      'Trousers'}): 1,
#           frozenset({'Denim', 'T-Shirts & Vests', 'Trainers'}): 376,
#           frozenset({'Boots',
#                      'Clutch Bags',
#                      'Sweaters & Knitwear',
#                      'Trousers'}): 42,
#           frozenset({'Shoulder Bags',
#                      'Sweaters & Knitwear',
#                      'T-Shirts & Vests',
#                      'Trainers',
#                      'Trousers'}): 138,
#           frozenset({'Belts',
#                      'Denim',
#                      'Earrings',
#                      'Scarves',
#                      'Sunglasses',
#                      'Tops'}): 4,
#           frozenset({'Earrings',
#                      'Pumps',
#                      'Tops',
#                      'Tote Bags',
#                      'Trousers'}): 69,
#           frozenset({'Earrings',
#                      'Shoulder Bags',
#                      'Skirts',
#                      'Tops',
#                      'Trainers'}): 62,
#           frozenset({'Coats', 'Tops'}): 2,
#           frozenset({'Boots',
#                      'Coats',
#                      'Earrings',
#                      'Knitwear',
#                      'Satchels & Cross Body Bags',
#                      'Trousers'}): 28,
#           frozenset({'Dresses',
#                      'Earrings',
#                      'Rings',
#                      'Sandals',
#                      'Shorts',
#                      'Shoulder Bags'}): 1,
#           frozenset({'Dresses', 'Earrings', 'Mini Bags', 'Mules'}): 279,
#           frozenset({'Boots',
#                      'Bracelets',
#                      'Earrings',
#                      'Shoulder Bags',
#                      'Skirts',
#                      'Tops'}): 44,
#           frozenset({'Belts',
#                      'Boots',
#                      'Earrings',
#                      'Keyrings & Chains',
#                      'Satchels & Cross Body Bags',
#                      'Sunglasses',
#                      'Trousers'}): 1,
#           frozenset({'Boots',
#                      'Coats',
#                      'Denim',
#                      'Earrings',
#                      'Knitwear',
#                      'Satchels & Cross Body Bags'}): 31,
#           frozenset({'Belts',
#                      'Coats',
#                      'Earrings',
#                      'Knitwear',
#                      'Loafers',
#                      'Tote Bags',
#                      'Trousers'}): 2,
#           frozenset({'Belt Bags',
#                      'Boots',
#                      'Hats',
#                      'Sweaters & Knitwear',
#                      'Trousers'}): 2,
#           frozenset({'Boots',
#                      'Face Masks',
#                      'Jackets',
#                      'Necklaces',
#                      'Phone, Computer & Gadgets',
#                      'Rings',
#                      'T-Shirts & Vests',
#                      'Tote Bags',
#                      'Trousers'}): 1,
#           frozenset({'Mules',
#                      'Necklaces',
#                      'Shoulder Bags',
#                      'Tops',
#                      'Trousers'}): 32,
#           frozenset({'Boots', 'Jackets', 'Shoulder Bags', 'Tops'}): 14,
#           frozenset({'Earrings', 'Knitwear', 'Sandals', 'Skirts'}): 73,
#           frozenset({'Bracelets',
#                      'Earrings',
#                      'Messenger Bags',
#                      'T-Shirts & Vests',
#                      'Trainers',
#                      'Trousers'}): 5,
#           frozenset({'Boots', 'Knitwear', 'Shoulder Bags', 'Trousers'}): 121,
#           frozenset({'Dresses',
#                      'Hair Accessories',
#                      'Mini Bags',
#                      'Sandals'}): 5,
#           frozenset({'Earrings',
#                      'Knitwear',
#                      'Sandals',
#                      'Shoulder Bags',
#                      'Skirts'}): 134,
#           frozenset({'Derby Shoes',
#                      'Hats',
#                      'Polo Shirts',
#                      'Shorts',
#                      'Shoulder Bags'}): 2,
#           frozenset({'Dresses', 'Earrings', 'Sandals', 'Shoulder Bags'}): 1349,
#           frozenset({'Earrings',
#                      'Jackets',
#                      'Tops',
#                      'Trainers',
#                      'Trousers'}): 109,
#           frozenset({'Denim',
#                      'Earrings',
#                      'Knitwear',
#                      'Mini Bags',
#                      'Necklaces',
#                      'Pumps',
#                      'Sunglasses'}): 1,
#           frozenset({'Ballerina Shoes',
#                      'Belts',
#                      'Earrings',
#                      'Rings',
#                      'Satchels & Cross Body Bags',
#                      'Tops',
#                      'Trousers'}): 1,
#           frozenset({'Earrings',
#                      'Knitwear',
#                      'Necklaces',
#                      'Sandals',
#                      'Tote Bags',
#                      'Trousers'}): 24,
#           frozenset({'Belts',
#                      'Jackets',
#                      'Messenger Bags',
#                      'Sweaters & Knitwear',
#                      'Trousers'}): 3,
#           frozenset({'Earrings',
#                      'Sandals',
#                      'Shoulder Bags',
#                      'Tops',
#                      'Trousers'}): 960,
#           frozenset({'Boots',
#                      'Coats',
#                      'Earrings',
#                      'Knitwear',
#                      'Shoulder Bags'}): 34,
#           frozenset({'Boots',
#                      'Earrings',
#                      'Satchels & Cross Body Bags',
#                      'Tops',
#                      'Trousers'}): 118,
#           frozenset({'Denim',
#                      'Jackets',
#                      'Loafers',
#                      'Shirts',
#                      'Shoulder Bags',
#                      'Socks'}): 1,
#           frozenset({'Clutch Bags', 'Knitwear', 'Mules', 'Necklaces'}): 3,
#           frozenset({'Glasses & Frames',
#                      'Knitwear',
#                      'Sandals',
#                      'Sunglasses',
#                      'Tops',
#                      'Trousers'}): 1,
#           frozenset({'Clutch Bags', 'Derby Shoes', 'Shirts'}): 1,
#           frozenset({'Bucket Bags', 'Skirts', 'Sunglasses', 'Tops'}): 2,
#           frozenset({'Bracelets',
#                      'Clutch Bags',
#                      'Earrings',
#                      'Rings',
#                      'Sandals',
#                      'Tops',
#                      'Trousers'}): 35,
#           frozenset({'Knitwear',
#                      'Sandals',
#                      'Satchels & Cross Body Bags',
#                      'Skirts'}): 15,
#           frozenset({'Boots',
#                      'Coats',
#                      'Earrings',
#                      'Satchels & Cross Body Bags',
#                      'Trousers'}): 4,
#           frozenset({'Shorts', 'Tops', 'Tote Bags'}): 77,
#           frozenset({'Boots', 'Knitwear', 'Tops', 'Trousers'}): 28,
#           frozenset({'Bracelets',
#                      'Dresses',
#                      'Earrings',
#                      'Rings',
#                      'Sandals',
#                      'Tote Bags'}): 138,
#           frozenset({'Necklaces',
#                      'Sunglasses',
#                      'Sweaters & Knitwear',
#                      'Trainers',
#                      'Trousers'}): 2,
#           frozenset({'Backpacks',
#                      'Earrings',
#                      'Necklaces',
#                      'Shorts',
#                      'Sunglasses',
#                      'Tops',
#                      'Trainers'}): 1,
#           frozenset({'Jackets', 'Necklaces', 'T-Shirts & Vests'}): 120,
#           frozenset({'Shirts',
#                      'Shoulder Bags',
#                      'T-Shirts & Vests',
#                      'Trainers',
#                      'Trousers'}): 49,
#           frozenset({'Backpacks',
#                      'Bracelets',
#                      'Hats',
#                      'T-Shirts & Vests',
#                      'Trainers'}): 7,
#           frozenset({'Boots', 'Denim', 'Jackets', 'T-Shirts & Vests'}): 164,
#           frozenset({'Bracelets', 'T-Shirts & Vests', 'Trainers'}): 13,
#           frozenset({'Earrings',
#                      'Jackets',
#                      'Knitwear',
#                      'Mules',
#                      'Shoulder Bags',
#                      'Sunglasses',
#                      'Trousers'}): 7,
#           frozenset({'Boots', 'Coats', 'Hats', 'Sweaters & Knitwear'}): 2,
#           frozenset({'Clutch Bags',
#                      'Earrings',
#                      'Tops',
#                      'Trainers',
#                      'Trousers'}): 42,
#           frozenset({'Denim',
#                      'Messenger Bags',
#                      'Sweaters & Knitwear',
#                      'Trainers'}): 188,
#           frozenset({'Dresses',
#                      'Earrings',
#                      'Necklaces',
#                      'Sandals',
#                      'Shoulder Bags',
#                      'Sunglasses'}): 28,
#           frozenset({'Hair Accessories', 'Tops', 'Trousers'}): 6,
#           frozenset({'Denim', 'Derby Shoes', 'Jackets', 'Tote Bags'}): 5,
#           frozenset({'Scarves',
#                      'Shirts',
#                      'Sweaters & Knitwear',
#                      'Trainers'}): 4,
#           frozenset({'Belts',
#                      'Clutch Bags',
#                      'Denim',
#                      'Rings',
#                      'T-Shirts & Vests',
#                      'Trainers'}): 1,
#           frozenset({'Bodies', 'Boots', 'Tops', 'Trousers'}): 1,
#           frozenset({'Shorts',
#                      'Sweaters & Knitwear',
#                      'T-Shirts & Vests',
#                      'Trainers'}): 275,
#           frozenset({'Boots', 'Denim', 'Earrings', 'Tops', 'Tote Bags'}): 184,
#           frozenset({'Jackets',
#                      'Sandals',
#                      'Shoulder Bags',
#                      'Tops',
#                      'Trousers'}): 98,
#           frozenset({'Jackets',
#                      'T-Shirts & Vests',
#                      'Tote Bags',
#                      'Trainers',
#                      'Trousers'}): 226,
#           frozenset({'Earrings',
#                      'Rings',
#                      'Sandals',
#                      'Shorts',
#                      'Tops',
#                      'Tote Bags'}): 39,
#           frozenset({'Boots',
#                      'Earrings',
#                      'Knitwear',
#                      'Shoulder Bags',
#                      'Sunglasses',
#                      'Trousers'}): 122,
#           frozenset({'Boots',
#                      'Clutch Bags',
#                      'Earrings',
#                      'Knitwear',
#                      'Trousers'}): 111,
#           frozenset({'Belt Bags',
#                      'Shorts',
#                      'Sweaters & Knitwear',
#                      'Trainers'}): 130,
#           frozenset({'Dresses', 'Sandals', 'Shoulder Bags', 'Skirts'}): 2,
#           frozenset({'Bracelets', 'Jackets', 'Trousers'}): 74,
#           frozenset({'Earrings', 'Jackets', 'Tops'}): 113,
#           frozenset({'Boots', 'Dresses', 'Tote Bags'}): 139,
#           frozenset({'Earrings', 'Knitwear', 'Skirts'}): 70,
#           frozenset({'Coats', 'Denim', 'T-Shirts & Vests', 'Tote Bags'}): 2,
#           frozenset({'Boots',
#                      'Denim',
#                      'Messenger Bags',
#                      'Necklaces',
#                      'Sweaters & Knitwear'}): 5,
#           frozenset({'Bracelets',
#                      'Jackets',
#                      'Sweaters & Knitwear',
#                      'Trousers'}): 19,
#           frozenset({'Boots',
#                      'Earrings',
#                      'Knitwear',
#                      'Rings',
#                      'Tops',
#                      'Tote Bags',
#                      'Trousers'}): 6,
#           frozenset({'Messenger Bags',
#                      'Shorts',
#                      'T-Shirts & Vests',
#                      'Trainers'}): 257,
#           frozenset({'Dresses',
#                      'Earrings',
#                      'Mini Bags',
#                      'Mules',
#                      'Sunglasses'}): 38,
#           frozenset({'Jackets',
#                      'Knitwear',
#                      'Sandals',
#                      'Shoulder Bags',
#                      'Skirts'}): 6,
#           frozenset({'Earrings',
#                      'Sandals',
#                      'Tops',
#                      'Tote Bags',
#                      'Trousers'}): 761,
#           frozenset({'Shirts', 'Trainers', 'Trousers'}): 283,
#           frozenset({'Loungewear', 'Sandals', 'Shoulder Bags'}): 2,
#           frozenset({'Bodies',
#                      'Earrings',
#                      'Sandals',
#                      'Shoulder Bags',
#                      'Trousers'}): 5,
#           frozenset({'Denim',
#                      'Earrings',
#                      'Sunglasses',
#                      'Tops',
#                      'Tote Bags',
#                      'Trainers'}): 22,
#           frozenset({'Dresses', 'Earrings', 'Rings', 'Sandals'}): 134,
#           frozenset({'Earrings',
#                      'Scarves',
#                      'Skirts',
#                      'Trainers',
#                      'Trousers'}): 1,
#           frozenset({'Glasses & Frames',
#                      'Messenger Bags',
#                      'Shirts',
#                      'Sweaters & Knitwear',
#                      'Trainers',
#                      'Trousers'}): 1,
#           frozenset({'Face Masks',
#                      'Hats',
#                      'Performance Shorts',
#                      'Tops',
#                      'Trainers'}): 1,
#           frozenset({'Belts', 'Derby Shoes', 'Jackets', 'Polo Shirts'}): 1,
#           frozenset({'Earrings',
#                      'Sandals',
#                      'Shorts',
#                      'Tops',
#                      'Tote Bags'}): 393,
#           frozenset({'Clutch Bags',
#                      'Loafers',
#                      'Shirts',
#                      'Sweaters & Knitwear',
#                      'Ties & Bow Ties'}): 2,
#           frozenset({'Backpacks',
#                      'Bracelets',
#                      'Necklaces',
#                      'Shirts',
#                      'T-Shirts & Vests',
#                      'Trainers',
#                      'Trousers'}): 3,
#           frozenset({'Messenger Bags',
#                      'Rings',
#                      'Shorts',
#                      'T-Shirts & Vests',
#                      'Trainers'}): 14,
#           frozenset({'Luggage & Holdalls', 'Shorts', 'Tops', 'Trainers'}): 4,
#           frozenset({'Belts',
#                      'Denim',
#                      'Earrings',
#                      'Glasses & Frames',
#                      'Jackets',
#                      'Satchels & Cross Body Bags',
#                      'Sunglasses',
#                      'Tops',
#                      'Trainers'}): 2,
#           frozenset({'Boots',
#                      'Earrings',
#                      'Knitwear',
#                      'Shoulder Bags',
#                      'Skirts'}): 221,
#           frozenset({'Boots', 'Dresses', 'Earrings'}): 199,
#           frozenset({'Boots', 'Shirts', 'Suits'}): 2,
#           frozenset({'Boots',
#                      'Coats',
#                      'Denim',
#                      'Scarves',
#                      'Sweaters & Knitwear',
#                      'Tote Bags'}): 3,
#           frozenset({'Denim', 'Knitwear', 'Scarves', 'Tops'}): 9,
#           frozenset({'Denim',
#                      'Earrings',
#                      'Flip Flops & Slides',
#                      'Knitwear',
#                      'Tops'}): 4,
#           frozenset({'Earrings',
#                      'Jackets',
#                      'Keyrings & Chains',
#                      'Sandals',
#                      'Shoulder Bags',
#                      'Sunglasses',
#                      'Trousers'}): 1,
#           frozenset({'Coats',
#                      'Derby Shoes',
#                      'Shirts',
#                      'T-Shirts & Vests',
#                      'Trousers'}): 5,
#           frozenset({'Belt Bags',
#                      'Sandals',
#                      'T-Shirts & Vests',
#                      'Trousers'}): 11,
#           frozenset({'Boots',
#                      'Clutch Bags',
#                      'Earrings',
#                      'Knitwear',
#                      'Necklaces',
#                      'Rings',
#                      'Skirts'}): 1,
#           frozenset({'Bracelets',
#                      'Clutch Bags',
#                      'Dresses',
#                      'Earrings',
#                      'Mules',
#                      'Rings'}): 22,
#           frozenset({'Earrings', 'Knitwear', 'Mules', 'Tote Bags'}): 31,
#           frozenset({'Belts',
#                      'Boots',
#                      'Dresses',
#                      'Necklaces',
#                      'Shoulder Bags',
#                      'Sunglasses'}): 1,
#           frozenset({'Boots',
#                      'Earrings',
#                      'Knitwear',
#                      'Skirts',
#                      'Tote Bags'}): 129,
#           frozenset({'Tote Bags', 'Trainers', 'Trousers'}): 26,
#           frozenset({'Knitwear', 'Skirts', 'Tote Bags'}): 31,
#           frozenset({'Necklaces',
#                      'Shoulder Bags',
#                      'Sunglasses',
#                      'T-Shirts & Vests',
#                      'Trousers'}): 3,
#           frozenset({'Boots',
#                      'Bracelets',
#                      'Clutch Bags',
#                      'Denim',
#                      'Polo Shirts',
#                      'Sunglasses',
#                      'Wallets & Cardholders'}): 1,
#           frozenset({'Bracelets', 'Denim', 'Jackets', 'Tops'}): 11,
#           frozenset({'Belt Bags',
#                      'T-Shirts & Vests',
#                      'Trainers',
#                      'Trousers'}): 180,
#           frozenset({'Jackets',
#                      'Sandals',
#                      'Shirts',
#                      'Tote Bags',
#                      'Trousers'}): 4,
#           frozenset({'Earrings',
#                      'Hats',
#                      'Shoulder Bags',
#                      'Tops',
#                      'Trainers'}): 18,
#           frozenset({'Bracelets', 'Sweaters & Knitwear', 'Trainers'}): 8,
#           frozenset({'Boots',
#                      'Denim',
#                      'Shoulder Bags',
#                      'Sweaters & Knitwear'}): 64,
#           frozenset({'Brogues & Oxfords',
#                      'Earrings',
#                      'Hats',
#                      'Jackets',
#                      'Shoulder Bags'}): 2,
#           frozenset({'Denim',
#                      'Necklaces',
#                      'Sunglasses',
#                      'T-Shirts & Vests'}): 3,
#           frozenset({'Hats',
#                      'Sandals',
#                      'Shirts',
#                      'Shorts',
#                      'T-Shirts & Vests'}): 3,
#           frozenset({'Backpacks',
#                      'Earrings',
#                      'Jackets',
#                      'Rings',
#                      'Tops',
#                      'Trousers'}): 2,
#           frozenset({'Backpacks',
#                      'Boots',
#                      'Jackets',
#                      'Sweaters & Knitwear',
#                      'Trousers'}): 74,
#           frozenset({'Earrings', 'Sunglasses', 'Tops'}): 36,
#           frozenset({'Dresses', 'Necklaces', 'Sandals'}): 32,
#           frozenset({'Earrings', 'Rings', 'Tops', 'Trainers'}): 2,
#           frozenset({'Jackets',
#                      'Sweaters & Knitwear',
#                      'Trainers',
#                      'Trousers'}): 488,
#           frozenset({'Earrings',
#                      'Necklaces',
#                      'Rings',
#                      'Sandals',
#                      'Shorts',
#                      'Shoulder Bags',
#                      'Tops'}): 5,
#           frozenset({'Boots', 'Shorts', 'Shoulder Bags', 'Tops'}): 32,
#           frozenset({'Denim', 'Sandals', 'Tops', 'Tote Bags'}): 154,
#           frozenset({'Bracelets',
#                      'Sweaters & Knitwear',
#                      'T-Shirts & Vests',
#                      'Trousers'}): 10,
#           frozenset({'Boots', 'Knitwear', 'Skiwear'}): 8,
#           frozenset({'Performance Trousers',
#                      'Sweaters & Knitwear',
#                      'Tote Bags',
#                      'Trainers'}): 26,
#           frozenset({'Bracelets',
#                      'Earrings',
#                      'Mini Bags',
#                      'Pumps',
#                      'Tops',
#                      'Trousers'}): 10,
#           frozenset({'Rings',
#                      'Shorts',
# ...
#                      'Shoulder Bags',
#                      'Sunglasses',
#                      'Sweaters & Knitwear'}): 4,
#           frozenset({'Belts',
#                      'Clutch Bags',
#                      'Jackets',
#                      'Loafers',
#                      'Shirts',
#                      'Sunglasses',
#                      'Trousers'}): 9,
#           frozenset({'Earrings',
#                      'Knitwear',
#                      'Sandals',
#                      'Tote Bags',
#                      'Trousers'}): 223,
#           frozenset({'Necklaces',
#                      'Sandals',
#                      'Shoulder Bags',
#                      'Tops',
#                      'Trousers'}): 89,
#           frozenset({'Boots',
#                      'Coats',
#                      'Earrings',
#                      'Tops',
#                      'Tote Bags',
#                      'Trousers'}): 89,
#           frozenset({'Clutch Bags',
#                      'Earrings',
#                      'Hair Accessories',
#                      'Sandals',
#                      'Skirts',
#                      'Tops'}): 22,
#           frozenset({'Clutch Bags', 'Dresses', 'Earrings', 'Mules'}): 225,
#           frozenset({'Denim',
#                      'Loafers',
#                      'Shoulder Bags',
#                      'Sweaters & Knitwear',
#                      'T-Shirts & Vests'}): 1,
#           frozenset({'Boots',
#                      'Coats',
#                      'Denim',
#                      'Earrings',
#                      'Shoulder Bags'}): 15,
#           frozenset({'Clutch Bags',
#                      'Polo Shirts',
#                      'Trainers',
#                      'Trousers'}): 42,
#           frozenset({'Earrings', 'Mules', 'Shoulder Bags', 'Tops'}): 29,
#           frozenset({'Boots', 'Denim', 'Tops', 'Tote Bags'}): 91,
#           frozenset({'Boots',
#                      'Sweaters & Knitwear',
#                      'T-Shirts & Vests',
#                      'Trousers'}): 90,
#           frozenset({'Bodies',
#                      'Boots',
#                      'Earrings',
#                      'Rings',
#                      'Shoulder Bags',
#                      'Tops',
#                      'Trousers'}): 4,
#           frozenset({'Polo Shirts', 'Sandals', 'Shorts'}): 42,
#           frozenset({'Clutch Bags', 'Dresses', 'Earrings', 'Pumps'}): 125,
#           frozenset({'Belts',
#                      'Denim',
#                      'Jackets',
#                      'Oxford Shoes',
#                      'Shirts',
#                      'Ties & Bow Ties'}): 4,
#           frozenset({'Bracelets',
#                      'Clutch Bags',
#                      'Denim',
#                      'Jackets',
#                      'Rings',
#                      'Shirts',
#                      'Sweaters & Knitwear'}): 1,
#           frozenset({'Shoulder Bags', 'Tops', 'Trousers'}): 204,
#           frozenset({'Flip Flops & Slides',
#                      'Shirts',
#                      'Sunglasses',
#                      'T-Shirts & Vests',
#                      'Trousers'}): 2,
#           frozenset({'Denim',
#                      'Earrings',
#                      'Glasses & Frames',
#                      'Shoulder Bags',
#                      'Sunglasses',
#                      'Tops',
#                      'Trainers'}): 4,
#           frozenset({'Sweaters & Knitwear', 'Tote Bags', 'Trainers'}): 70,
#           frozenset({'Dresses', 'Pumps', 'Satchels & Cross Body Bags'}): 54,
#           frozenset({'Belts', 'Denim', 'Knitwear', 'Tote Bags'}): 1,
#           frozenset({'Boots',
#                      'Bracelets',
#                      'Earrings',
#                      'Mini Bags',
#                      'Rings',
#                      'Tops',
#                      'Trousers'}): 13,
#           frozenset({'Necklaces',
#                      'Sweaters & Knitwear',
#                      'T-Shirts & Vests'}): 32,
#           frozenset({'Earrings',
#                      'Mini Bags',
#                      'Skirts',
#                      'Sunglasses',
#                      'Tops'}): 20,
#           frozenset({'Belts',
#                      'Earrings',
#                      'Pumps',
#                      'Shoulder Bags',
#                      'Tops',
#                      'Trousers'}): 4,
#           frozenset({'Boots', 'Coats', 'Denim', 'Shirts'}): 4,
#           frozenset({'Jackets', 'Skirts', 'Tops'}): 74,
#           frozenset({'Derby Shoes', 'Jackets', 'Shirts', 'Trousers'}): 42,
#           frozenset({'Clutch Bags',
#                      'Hats',
#                      'Knitwear',
#                      'Phone, Computer & Gadgets',
#                      'Sandals',
#                      'Shorts'}): 1,
#           frozenset({'Bracelets',
#                      'Dresses',
#                      'Earrings',
#                      'Mini Bags',
#                      'Pumps'}): 18,
#           frozenset({'Earrings',
#                      'Jackets',
#                      'Mini Bags',
#                      'Sandals',
#                      'Tailoring'}): 1,
#           frozenset({'Coats',
#                      'Messenger Bags',
#                      'T-Shirts & Vests',
#                      'Trainers',
#                      'Trousers'}): 8,
#           frozenset({'Earrings', 'Mini Bags', 'Shorts', 'Tops'}): 16,
#           frozenset({'Boots', 'Shorts', 'Sweaters & Knitwear'}): 70,
#           frozenset({'Clutch Bags', 'Shirts', 'Shorts', 'Trainers'}): 26,
#           frozenset({'Bodies',
#                      'Bucket Bags',
#                      'Earrings',
#                      'Sandals',
#                      'Tops',
#                      'Trousers'}): 2,
#           frozenset({'Backpacks',
#                      'Phone, Computer & Gadgets',
#                      'Sweaters & Knitwear',
#                      'Trainers',
#                      'Trousers'}): 1,
#           frozenset({'Polo Shirts', 'Sandals', 'Tote Bags', 'Trousers'}): 15,
#           frozenset({'Belt Bags', 'Boots', 'Jackets', 'Shorts'}): 4,
#           frozenset({'Necklaces',
#                      'Shirts',
#                      'Shorts',
#                      'Tote Bags',
#                      'Trainers'}): 9,
#           frozenset({'Loafers', 'Mini Bags', 'Shirts', 'Trousers'}): 1,
#           frozenset({'Bracelets',
#                      'Messenger Bags',
#                      'Polo Shirts',
#                      'Sandals',
#                      'Shorts'}): 5,
#           frozenset({'Bracelets',
#                      'Jackets',
#                      'Sandals',
#                      'Shirts',
#                      'Tote Bags',
#                      'Trousers'}): 1,
#           frozenset({'Boots',
#                      'Denim',
#                      'Earrings',
#                      'Jackets',
#                      'Shoulder Bags',
#                      'Tops'}): 198,
#           frozenset({'Denim',
#                      'Derby Shoes',
#                      'Jackets',
#                      'Shirts',
#                      'Sweaters & Knitwear'}): 5,
#           frozenset({'Boots',
#                      'Earrings',
#                      'Skirts',
#                      'Sunglasses',
#                      'Tops',
#                      'Tote Bags'}): 64,
#           frozenset({'Shorts',
#                      'Sweaters & Knitwear',
#                      'T-Shirts & Vests',
#                      'Tote Bags',
#                      'Trainers'}): 133,
#           frozenset({'Boots',
#                      'Clutch Bags',
#                      'Loafers',
#                      'Necklaces',
#                      'Sweaters & Knitwear',
#                      'Trousers'}): 1,
#           frozenset({'Jackets',
#                      'Sandals',
#                      'Satchels & Cross Body Bags',
#                      'Trousers'}): 21,
#           frozenset({'Necklaces',
#                      'Shorts',
#                      'T-Shirts & Vests',
#                      'Trainers'}): 21,
#           frozenset({'Clutch Bags',
#                      'Earrings',
#                      'Knitwear',
#                      'Sandals',
#                      'Shorts'}): 38,
#           frozenset({'Clutch Bags',
#                      'Jackets',
#                      'T-Shirts & Vests',
#                      'Trainers',
#                      'Trousers'}): 64,
#           frozenset({'Boots', 'Dresses', 'Mini Bags'}): 80,
#           frozenset({'Dresses',
#                      'Earrings',
#                      'Fine Bracelets',
#                      'Mini Bags',
#                      'Sandals'}): 18,
#           frozenset({'Necklaces',
#                      'Sandals',
#                      'Satchels & Cross Body Bags',
#                      'Tops'}): 5,
#           frozenset({'Boots',
#                      'Denim',
#                      'Earrings',
#                      'Satchels & Cross Body Bags',
#                      'Tops'}): 143,
#           frozenset({'Clutch Bags',
#                      'Derby Shoes',
#                      'Scarves',
#                      'Shirts',
#                      'Sunglasses',
#                      'Trousers'}): 2,
#           frozenset({'Loungewear',
#                      'Mules',
#                      'Shoulder Bags',
#                      'Tops',
#                      'Trousers'}): 2,
#           frozenset({'Ballerina Shoes',
#                      'Coats',
#                      'Earrings',
#                      'Knitwear',
#                      'Necklaces',
#                      'Shoulder Bags',
#                      'Sunglasses',
#                      'Trousers'}): 1,
#           frozenset({'Brogues & Oxfords',
#                      'Satchels & Cross Body Bags',
#                      'Skirts',
#                      'Tops'}): 3,
#           frozenset({'Boots',
#                      'Jackets',
#                      'Shoulder Bags',
#                      'Tops',
#                      'Trousers'}): 88,
#           frozenset({'Boots',
#                      'Denim',
#                      'Earrings',
#                      'Satchels & Cross Body Bags',
#                      'Sunglasses',
#                      'Tops'}): 48,
#           frozenset({'Bracelets',
#                      'Denim',
#                      'Sandals',
#                      'Tops',
#                      'Tote Bags'}): 33,
#           frozenset({'Dresses', 'Mini Bags', 'Pumps'}): 87,
#           frozenset({'Bracelets',
#                      'Clutch Bags',
#                      'Mules',
#                      'Necklaces',
#                      'Performance Tops',
#                      'Skirts'}): 1,
#           frozenset({'Nightwear', 'Sandals', 'Shoulder Bags'}): 1,
#           frozenset({'Boots',
#                      'Dresses',
#                      'Earrings',
#                      'Hats',
#                      'Shoulder Bags'}): 23,
#           frozenset({'Jackets',
#                      'Sweaters & Knitwear',
#                      'Tote Bags',
#                      'Trousers'}): 18,
#           frozenset({'Earrings',
#                      'Hair Accessories',
#                      'Mini Bags',
#                      'Tops',
#                      'Trousers'}): 5,
#           frozenset({'Earrings',
#                      'Necklaces',
#                      'Sandals',
#                      'Tops',
#                      'Tote Bags',
#                      'Trousers'}): 68,
#           frozenset({'Knitwear',
#                      'Sandals',
#                      'Satchels & Cross Body Bags',
#                      'Shorts',
#                      'Skirts'}): 1,
#           frozenset({'Coats',
#                      'Earrings',
#                      'Face Masks',
#                      'Sandals',
#                      'Tops',
#                      'Tote Bags',
#                      'Trousers'}): 1,
#           frozenset({'Clutch Bags', 'Earrings', 'Knitwear', 'Sandals'}): 60,
#           frozenset({'Earrings',
#                      'Jackets',
#                      'Sandals',
#                      'Satchels & Cross Body Bags',
#                      'Shorts',
#                      'Tops'}): 33,
#           frozenset({'Knitwear', 'Tops', 'Tote Bags', 'Trainers'}): 7,
#           frozenset({'Denim', 'Earrings', 'Tops', 'Trainers'}): 99,
#           frozenset({'Hats',
#                      'Messenger Bags',
#                      'T-Shirts & Vests',
#                      'Trainers',
#                      'Trousers'}): 78,
#           frozenset({'Ballerina Shoes',
#                      'Bracelets',
#                      'Dresses',
#                      'Earrings',
#                      'Rings',
#                      'Shoulder Bags'}): 3,
#           frozenset({'Denim',
#                      'Messenger Bags',
#                      'Shirts',
#                      'Sweaters & Knitwear',
#                      'Trainers'}): 27,
#           frozenset({'Bracelets',
#                      'Messenger Bags',
#                      'Polo Shirts',
#                      'Shorts',
#                      'Trainers'}): 13,
#           frozenset({'Knitwear', 'Sandals', 'Satchels & Cross Body Bags'}): 28,
#           frozenset({'Boots',
#                      'Coats',
#                      'Messenger Bags',
#                      'Rings',
#                      'Sweaters & Knitwear',
#                      'Trousers'}): 8,
#           frozenset({'Rings',
#                      'Sweaters & Knitwear',
#                      'Trainers',
#                      'Trousers'}): 200,
#           frozenset({'Boots', 'Earrings', 'Knitwear', 'Shoulder Bags'}): 135,
#           frozenset({'Boots', 'Rings', 'Shirts', 'Tote Bags', 'Trousers'}): 10,
#           frozenset({'Bracelets', 'Necklaces', 'Skirts', 'Tops'}): 2,
#           frozenset({'Boots',
#                      'Clutch Bags',
#                      'Earrings',
#                      'Knitwear',
#                      'Sunglasses',
#                      'Trousers',
#                      'Wallets & Purses'}): 5,
#           frozenset({'Knitwear', 'Tops', 'Trainers', 'Trousers'}): 18,
#           frozenset({'Boots',
#                      'Coats',
#                      'Earrings',
#                      'Satchels & Cross Body Bags',
#                      'Tops',
#                      'Trousers'}): 43,
#           frozenset({'Laptop Bags & Briefcases',
#                      'Sweaters & Knitwear',
#                      'Trainers',
#                      'Trousers'}): 57,
#           frozenset({'Hair Accessories', 'Shorts', 'Ties', 'Tops'}): 1,
#           frozenset({'Bracelets',
#                      'Shirts',
#                      'Shorts',
#                      'T-Shirts & Vests',
#                      'Trainers'}): 7,
#           frozenset({'Boots',
#                      'Jackets',
#                      'Messenger Bags',
#                      'Rings',
#                      'Shirts',
#                      'Sunglasses',
#                      'Trousers',
#                      'Wallets & Cardholders'}): 2,
#           frozenset({'Boots',
#                      'Coats',
#                      'Earrings',
#                      'Shoulder Bags',
#                      'Tops',
#                      'Trousers'}): 88,
#           frozenset({'Bracelets',
#                      'Clutch Bags',
#                      'Loafers',
#                      'Shorts',
#                      'T-Shirts & Vests'}): 3,
#           frozenset({'Boots',
#                      'Clutch Bags',
#                      'Earrings',
#                      'Jackets',
#                      'Tops'}): 6,
#           frozenset({'Sandals', 'Skirts', 'Tops', 'Tote Bags'}): 138,
#           frozenset({'Earrings',
#                      'Mules',
#                      'Shoulder Bags',
#                      'Sunglasses',
#                      'Tops',
#                      'Trousers'}): 59,
#           frozenset({'Clutch Bags',
#                      'Coats',
#                      'Sweaters & Knitwear',
#                      'Trainers',
#                      'Trousers'}): 14,
#           frozenset({'Jackets', 'Polo Shirts', 'Trainers'}): 12,
#           frozenset({'Bracelets',
#                      'Sandals',
#                      'Shirts',
#                      'Tote Bags',
#                      'Trousers'}): 15,
#           frozenset({'Boots', 'Earrings', 'Jackets', 'Tops'}): 22,
#           frozenset({'Bracelets', 'Earrings', 'Necklaces', 'Tops'}): 3,
#           ...})}

# %% [markdown]
# # Predict - Using the category sets to rank the candidates

# %% [markdown]
# ### Use the file name generatad by evaluation/simple_split_dataset.ipynb here

# %%
incomplete_outfits_input = "../data/manual_outfits_testinput_1651692691.parquet"

# %%
test_outfits = pd.read_parquet(incomplete_outfits_input)
test_outfits.head()
# Out:
#    outfit_id                                  incomplete_outfit  \
# 0          0           [16260894, 15360881, 15781925, 16204075]
# 1          1  [15426616, 16035469, 18218977, 13893721, 13893...
# 2          2           [17484491, 16160567, 17503108, 13508028]
# 3          3           [17040752, 18205465, 16127776, 18203427]
# 7          7                     [13990742, 14371345, 16487493]
#
#                                           candidates
# 0  [16953540, 15843277, 16639054, 18203407, 17243...
# 1  [16359488, 18006145, 17565154, 17236069, 16666...
# 2  [16674563, 15180164, 16938764, 16917773, 18144...
# 3  [17425028, 16709508, 17220615, 16115468, 16631...
# 7  [18149250, 16299400, 17524105, 17168907, 17305...

# %%
def predict(model, incomplete_outfit, candidates):
    """
    This is the core of your model. In our example, we are going to use the toy model we build in the first part 
    of this notebook, but you are free to create your amazing model and use it here.
    Arguments:
        model: the outfits model
        incomplete_outfit: a list of product_id containing the outfit we want to complete
        candidates: a list of product_id that you are tasked to select the rigth product to complete the outfit
    Return
        A list of product_id sorted according your model
    """
    scores = []
    for candidate in candidates:
        outfit = incomplete_outfit + [candidate]
        try:
            categories = model["items_metadata"].loc[outfit]["product_category"].tolist()
            score = model["categories_sets"].get(frozenset(categories), 0)
        except KeyError:
            score = 0
        scores.append((score, candidate))
    return [
        candidate
        for _, candidate in sorted(scores, reverse=True)
    ]

test_outfits["predicted_products"] = test_outfits.apply(lambda row: predict(toy_model, row["incomplete_outfit"], row["candidates"]), axis=1)
test_outfits["predicted_product"] = test_outfits.apply(lambda row: row["predicted_products"][0], axis=1)
test_outfits.head()
# Out:
#    outfit_id                                  incomplete_outfit  \
# 0          0           [16260894, 15360881, 15781925, 16204075]
# 1          1  [15426616, 16035469, 18218977, 13893721, 13893...
# 2          2           [17484491, 16160567, 17503108, 13508028]
# 3          3           [17040752, 18205465, 16127776, 18203427]
# 7          7                     [13990742, 14371345, 16487493]
#
#                                           candidates  \
# 0  [16953540, 15843277, 16639054, 18203407, 17243...
# 1  [16359488, 18006145, 17565154, 17236069, 16666...
# 2  [16674563, 15180164, 16938764, 16917773, 18144...
# 3  [17425028, 16709508, 17220615, 16115468, 16631...
# 7  [18149250, 16299400, 17524105, 17168907, 17305...
#
#                                   predicted_products  predicted_product
# 0  [18203407, 18057462, 18012827, 17803125, 17534...           18203407
# 1  [18292694, 18217074, 18006145, 17793979, 17715...           18292694
# 2  [18361594, 18325923, 18219660, 18144908, 18111...           18361594
# 3  [17784236, 17754878, 17538910, 17425028, 17220...           17784236
# 7  [18149250, 17996819, 17524105, 17449640, 17389...           18149250

# %%
output_name = incomplete_outfits_input.replace(".parquet", "_predictions.csv")
output_columns = ["outfit_id", "predicted_product"]
test_outfits[output_columns].to_csv(output_name, header=True, index=False)

# %%
print(datetime.datetime.now())
# Out:
# 2022-05-22 21:21:57.874392

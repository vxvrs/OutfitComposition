# %% [markdown]
# This script is an example of how you could generate features from the product images. It also shows a simple way to read the images using ImageReader class.
#
# Here, we're using the last layer of a convolutional network named Resnet50 as the representatiion of the products.
# To run this script you need tensorflow instaled on you env, as well as, the numpy, pandas and PIL packages.
#
# In order to this script to work, we supose that the dataset images folder was unpacked in ../data/images

# %%
import os
import time
from pathlib import Path
from typing import Any, Dict, Set, Tuple, Union, List

import numpy as np
import pandas as pd
from PIL import UnidentifiedImageError
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array

IMAGES_ROOT_PATH = "../data/images"

class ImageReader:
    """Load product images from the uncompressed dir you downloaded the images file."""

    def __init__(self, images_root_path=IMAGES_ROOT_PATH):
        self._images_root_path = images_root_path
        self.image_size = (224, 224)
        if not Path(images_root_path).exists():
            raise ValueError(f"Path {images_root_path} does not exist")

    def exists(self, product_id: int) -> bool:
        """Verify that the cache has the given product ID.
        Args:
            product_id: int that represents the product id
        Returns: True if the product id is on cache.
        """
        path = self._local_image_path(product_id=product_id)
        return os.path.exists(path)

    def get(self, product_id: int, target_size: Tuple[int, int]) -> bytearray:
        """Get the image corresponding to the given product ID.
        Args:
            product_id: int that represents the product id
            target_size: Tuple[int, int] of the returned image
        Returns: bytearray representing the image.
        """
        path = self._local_image_path(product_id=product_id)
        try:
            img = image.load_img(path=path, target_size=target_size)
            return img
        except UnidentifiedImageError as image_error:
            print(f"error opening {path}")
            path.unlink()
            raise ValueError(image_error) from image_error
        except FileNotFoundError as image_error:
            print(f"FileNotFoundError {path}")
            raise ValueError(image_error) from image_error
    
    def get_batch(self, product_ids: List[int]):
        images = []
        products_with_images = []
        for product_id in product_ids:
            try:
                image = self.get(
                    product_id=product_id,
                    target_size=self.image_size,
                )
                image = img_to_array(image)
                images.append(image)
                products_with_images.append(product_id)
            except (IOError, ValueError) as ex:
                pass
        
        return np.stack(images), products_with_images

    def store(self, product_id: int, data: bytes) -> None:
        """Store the image corresponding to the given product ID.
        Args:
            product_id: int that represents the product id
            article_photo_id: int that represents the photo_id
            data: bytes representing the image to be stored.
        """
        if len(data) == 0:
            raise ValueError("Trying to store a empty image file")
        path = self._local_image_path(
            product_id=product_id
        )

        path.parent.mkdir(parents=True, exist_ok=True)
        try:
            with open(path, "wb") as img_file:
                img_file.write(data)
        except PermissionError:
            print(f"Error while writing image {str(path)}")

    def _local_image_path(
        self, product_id: Union[int, np.int64]
    ) -> Path:
        if not isinstance(product_id, (int, np.integer)):
            raise ValueError(
                f"product_id and article_photo_id should be integers, "
                f"not {type(product_id)}"
            )
        name = f"{product_id}.jpg"
        path = self._get_folder_path(product_id=product_id)
        return Path(self._images_root_path, path, name)

    @staticmethod
    def _get_folder_path(product_id: int) -> str:
        """Generates a path of a given product ID to download it from CDN
        Args:
            product_id:
        Returns:
        Examples:
            11501771 -> 11/50/17/71
        """
        product_id_str = str(product_id)
        return "/".join(
            [product_id_str[i : i + 2] for i in range(0, len(product_id_str), 2)]
        )

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.layers import Flatten

def get_all_product_ids() -> List[int]:
    items_metadata = pd.read_parquet("../data/items_metadata.parquet")
    return items_metadata["product_id"].unique().tolist()

def get_cnn_model(image_size):
    resnet50 = Sequential()
    resnet50.add(
        ResNet50(
            input_shape=image_size,
            include_top=False,
            weights="imagenet",
            pooling="avg",
        )
    )
    resnet50.add(Flatten())
    return resnet50

def batch_predict(product_ids: List[int], resnet50: Sequential, cache: LocalCache):
    product_ids_with_embeddings = []
    product_embeddings = []
    for i in range(0, len(product_ids), 128):
        batch = product_ids[i: i+128]
        try:
            batch_images, batch_product_ids = cache.get_batch(batch)
            batch_images = preprocess_input(batch_images)
            batch_predictions = resnet50.predict(batch_images)
            product_embeddings.append(batch_predictions)
            product_ids_with_embeddings += batch_product_ids
        except ValueError:
            pass
    return product_ids_with_embeddings, np.vstack(product_embeddings)

# %%
cache = LocalCache()
product_ids = get_all_product_ids()
resnet50 = get_cnn_model(image_size=(*cache.image_size, 3))

product_ids_with_embeddings, product_embeddings = batch_predict(product_ids, resnet50, cache)

embeddings = pd.DataFrame(
    product_embeddings,
    columns=[f"embedding_{x}" for x in range(product_embeddings.shape[1])],
)
embeddings["product_id"] = product_ids_with_embeddings
# Out:
# FileNotFoundError ../data/images/10/0/100.jpg
# FileNotFoundError ../data/images/10/1/101.jpg
# FileNotFoundError ../data/images/10/2/102.jpg
# FileNotFoundError ../data/images/10/3/103.jpg
# FileNotFoundError ../data/images/10/4/104.jpg
# FileNotFoundError ../data/images/10/5/105.jpg
# FileNotFoundError ../data/images/10/6/106.jpg
# FileNotFoundError ../data/images/10/7/107.jpg
# FileNotFoundError ../data/images/10/8/108.jpg
# FileNotFoundError ../data/images/10/9/109.jpg
# FileNotFoundError ../data/images/11/0/110.jpg
# FileNotFoundError ../data/images/11/1/111.jpg
# FileNotFoundError ../data/images/11/2/112.jpg
# FileNotFoundError ../data/images/11/3/113.jpg
# FileNotFoundError ../data/images/11/4/114.jpg
# FileNotFoundError ../data/images/11/5/115.jpg
# FileNotFoundError ../data/images/11/6/116.jpg
# FileNotFoundError ../data/images/11/7/117.jpg
# FileNotFoundError ../data/images/11/8/118.jpg
# FileNotFoundError ../data/images/11/9/119.jpg
# FileNotFoundError ../data/images/12/0/120.jpg
# FileNotFoundError ../data/images/12/1/121.jpg
# FileNotFoundError ../data/images/12/2/122.jpg
# FileNotFoundError ../data/images/12/3/123.jpg
# FileNotFoundError ../data/images/12/4/124.jpg
# FileNotFoundError ../data/images/12/5/125.jpg
# FileNotFoundError ../data/images/12/6/126.jpg
# FileNotFoundError ../data/images/12/7/127.jpg
# FileNotFoundError ../data/images/12/8/128.jpg
# FileNotFoundError ../data/images/12/9/129.jpg
# FileNotFoundError ../data/images/13/0/130.jpg
# FileNotFoundError ../data/images/13/1/131.jpg
# FileNotFoundError ../data/images/13/2/132.jpg
# FileNotFoundError ../data/images/13/3/133.jpg
# FileNotFoundError ../data/images/13/4/134.jpg
# FileNotFoundError ../data/images/13/5/135.jpg
# FileNotFoundError ../data/images/13/6/136.jpg
# FileNotFoundError ../data/images/13/7/137.jpg
# FileNotFoundError ../data/images/13/8/138.jpg
# FileNotFoundError ../data/images/13/9/139.jpg
# FileNotFoundError ../data/images/14/0/140.jpg
# FileNotFoundError ../data/images/14/1/141.jpg
# FileNotFoundError ../data/images/14/2/142.jpg
# FileNotFoundError ../data/images/14/3/143.jpg
# FileNotFoundError ../data/images/14/4/144.jpg
# FileNotFoundError ../data/images/14/5/145.jpg
# FileNotFoundError ../data/images/14/6/146.jpg
# FileNotFoundError ../data/images/14/7/147.jpg
# FileNotFoundError ../data/images/14/8/148.jpg
# FileNotFoundError ../data/images/14/9/149.jpg
# FileNotFoundError ../data/images/15/0/150.jpg
# FileNotFoundError ../data/images/15/1/151.jpg
# FileNotFoundError ../data/images/15/2/152.jpg
# FileNotFoundError ../data/images/15/3/153.jpg
# FileNotFoundError ../data/images/15/4/154.jpg
# FileNotFoundError ../data/images/15/5/155.jpg
# FileNotFoundError ../data/images/15/6/156.jpg
# FileNotFoundError ../data/images/15/7/157.jpg
# FileNotFoundError ../data/images/15/8/158.jpg
# FileNotFoundError ../data/images/15/9/159.jpg
# FileNotFoundError ../data/images/16/0/160.jpg
# FileNotFoundError ../data/images/16/1/161.jpg
# FileNotFoundError ../data/images/16/2/162.jpg
# FileNotFoundError ../data/images/16/3/163.jpg
# FileNotFoundError ../data/images/16/4/164.jpg
# FileNotFoundError ../data/images/16/5/165.jpg
# FileNotFoundError ../data/images/16/6/166.jpg
# FileNotFoundError ../data/images/16/7/167.jpg
# FileNotFoundError ../data/images/16/8/168.jpg
# FileNotFoundError ../data/images/16/9/169.jpg
# FileNotFoundError ../data/images/17/0/170.jpg
# FileNotFoundError ../data/images/17/1/171.jpg
# FileNotFoundError ../data/images/17/2/172.jpg
# FileNotFoundError ../data/images/17/3/173.jpg
# FileNotFoundError ../data/images/17/4/174.jpg
# FileNotFoundError ../data/images/17/5/175.jpg
# FileNotFoundError ../data/images/17/6/176.jpg
# FileNotFoundError ../data/images/17/7/177.jpg
# FileNotFoundError ../data/images/17/8/178.jpg
# FileNotFoundError ../data/images/17/9/179.jpg
# FileNotFoundError ../data/images/18/0/180.jpg
# FileNotFoundError ../data/images/18/1/181.jpg
# FileNotFoundError ../data/images/18/2/182.jpg
# FileNotFoundError ../data/images/18/3/183.jpg
# FileNotFoundError ../data/images/18/4/184.jpg
# FileNotFoundError ../data/images/18/5/185.jpg
# FileNotFoundError ../data/images/18/6/186.jpg
# FileNotFoundError ../data/images/18/7/187.jpg
# FileNotFoundError ../data/images/18/8/188.jpg
# FileNotFoundError ../data/images/18/9/189.jpg
# FileNotFoundError ../data/images/19/0/190.jpg
# FileNotFoundError ../data/images/19/1/191.jpg
# FileNotFoundError ../data/images/19/2/192.jpg
# FileNotFoundError ../data/images/19/3/193.jpg
# FileNotFoundError ../data/images/19/4/194.jpg
# FileNotFoundError ../data/images/19/5/195.jpg
# FileNotFoundError ../data/images/19/6/196.jpg
# FileNotFoundError ../data/images/19/7/197.jpg
# FileNotFoundError ../data/images/19/8/198.jpg
# FileNotFoundError ../data/images/19/9/199.jpg
# FileNotFoundError ../data/images/20/0/200.jpg
# FileNotFoundError ../data/images/20/1/201.jpg
# FileNotFoundError ../data/images/20/2/202.jpg
# FileNotFoundError ../data/images/20/3/203.jpg
# FileNotFoundError ../data/images/20/4/204.jpg
# FileNotFoundError ../data/images/20/5/205.jpg
# FileNotFoundError ../data/images/20/6/206.jpg
# FileNotFoundError ../data/images/20/7/207.jpg
# FileNotFoundError ../data/images/20/8/208.jpg
# FileNotFoundError ../data/images/20/9/209.jpg
# FileNotFoundError ../data/images/21/0/210.jpg
# FileNotFoundError ../data/images/21/1/211.jpg
# FileNotFoundError ../data/images/21/2/212.jpg
# FileNotFoundError ../data/images/21/3/213.jpg
# FileNotFoundError ../data/images/21/4/214.jpg
# FileNotFoundError ../data/images/21/5/215.jpg
# FileNotFoundError ../data/images/21/6/216.jpg
# FileNotFoundError ../data/images/21/7/217.jpg
# FileNotFoundError ../data/images/21/8/218.jpg
# FileNotFoundError ../data/images/21/9/219.jpg
# FileNotFoundError ../data/images/22/0/220.jpg
# FileNotFoundError ../data/images/22/1/221.jpg
# FileNotFoundError ../data/images/22/2/222.jpg
# FileNotFoundError ../data/images/22/3/223.jpg
# FileNotFoundError ../data/images/22/4/224.jpg
# FileNotFoundError ../data/images/22/5/225.jpg
# FileNotFoundError ../data/images/22/6/226.jpg
# FileNotFoundError ../data/images/22/7/227.jpg
# FileNotFoundError ../data/images/22/8/228.jpg
# FileNotFoundError ../data/images/22/9/229.jpg
# FileNotFoundError ../data/images/23/0/230.jpg
# FileNotFoundError ../data/images/23/1/231.jpg
# FileNotFoundError ../data/images/23/2/232.jpg
# FileNotFoundError ../data/images/23/3/233.jpg
# FileNotFoundError ../data/images/23/4/234.jpg
# FileNotFoundError ../data/images/23/5/235.jpg
# FileNotFoundError ../data/images/23/6/236.jpg
# FileNotFoundError ../data/images/23/7/237.jpg
# FileNotFoundError ../data/images/23/8/238.jpg
# FileNotFoundError ../data/images/23/9/239.jpg
# FileNotFoundError ../data/images/24/0/240.jpg
# FileNotFoundError ../data/images/24/1/241.jpg
# FileNotFoundError ../data/images/24/2/242.jpg
# FileNotFoundError ../data/images/24/3/243.jpg
# FileNotFoundError ../data/images/24/4/244.jpg
# FileNotFoundError ../data/images/24/5/245.jpg
# FileNotFoundError ../data/images/24/6/246.jpg
# FileNotFoundError ../data/images/24/7/247.jpg
# FileNotFoundError ../data/images/24/8/248.jpg
# FileNotFoundError ../data/images/24/9/249.jpg
# FileNotFoundError ../data/images/25/0/250.jpg
# FileNotFoundError ../data/images/25/1/251.jpg
# FileNotFoundError ../data/images/25/2/252.jpg
# FileNotFoundError ../data/images/25/3/253.jpg
# FileNotFoundError ../data/images/25/4/254.jpg
# FileNotFoundError ../data/images/25/5/255.jpg
# FileNotFoundError ../data/images/25/6/256.jpg
# FileNotFoundError ../data/images/25/7/257.jpg
# FileNotFoundError ../data/images/25/8/258.jpg
# FileNotFoundError ../data/images/25/9/259.jpg
# FileNotFoundError ../data/images/26/0/260.jpg
# FileNotFoundError ../data/images/26/1/261.jpg
# FileNotFoundError ../data/images/26/2/262.jpg
# FileNotFoundError ../data/images/26/3/263.jpg
# FileNotFoundError ../data/images/26/4/264.jpg
# FileNotFoundError ../data/images/26/5/265.jpg
# FileNotFoundError ../data/images/26/6/266.jpg
# FileNotFoundError ../data/images/26/7/267.jpg
# FileNotFoundError ../data/images/26/8/268.jpg
# FileNotFoundError ../data/images/26/9/269.jpg
# FileNotFoundError ../data/images/27/0/270.jpg
# FileNotFoundError ../data/images/27/1/271.jpg
# FileNotFoundError ../data/images/27/2/272.jpg
# FileNotFoundError ../data/images/27/3/273.jpg
# FileNotFoundError ../data/images/27/4/274.jpg
# FileNotFoundError ../data/images/27/5/275.jpg
# FileNotFoundError ../data/images/27/6/276.jpg
# FileNotFoundError ../data/images/27/8/278.jpg
# FileNotFoundError ../data/images/27/9/279.jpg
# FileNotFoundError ../data/images/28/0/280.jpg
# FileNotFoundError ../data/images/28/1/281.jpg
# FileNotFoundError ../data/images/28/2/282.jpg
# FileNotFoundError ../data/images/28/3/283.jpg
# FileNotFoundError ../data/images/28/4/284.jpg
# FileNotFoundError ../data/images/28/5/285.jpg
# FileNotFoundError ../data/images/28/6/286.jpg
# FileNotFoundError ../data/images/28/7/287.jpg
# FileNotFoundError ../data/images/28/8/288.jpg
# FileNotFoundError ../data/images/28/9/289.jpg
# FileNotFoundError ../data/images/29/0/290.jpg
# FileNotFoundError ../data/images/29/1/291.jpg
# FileNotFoundError ../data/images/29/2/292.jpg
# FileNotFoundError ../data/images/29/3/293.jpg
# FileNotFoundError ../data/images/29/4/294.jpg
# FileNotFoundError ../data/images/29/5/295.jpg
# FileNotFoundError ../data/images/29/6/296.jpg
# FileNotFoundError ../data/images/29/7/297.jpg
# FileNotFoundError ../data/images/29/8/298.jpg
# FileNotFoundError ../data/images/29/9/299.jpg
# FileNotFoundError ../data/images/30/0/300.jpg
# FileNotFoundError ../data/images/30/1/301.jpg
# FileNotFoundError ../data/images/30/2/302.jpg
# FileNotFoundError ../data/images/30/3/303.jpg
# FileNotFoundError ../data/images/30/4/304.jpg
# FileNotFoundError ../data/images/30/5/305.jpg
# FileNotFoundError ../data/images/30/6/306.jpg
# FileNotFoundError ../data/images/30/7/307.jpg
# FileNotFoundError ../data/images/30/8/308.jpg
# FileNotFoundError ../data/images/30/9/309.jpg
# FileNotFoundError ../data/images/31/0/310.jpg
# FileNotFoundError ../data/images/31/1/311.jpg
# FileNotFoundError ../data/images/31/2/312.jpg
# FileNotFoundError ../data/images/31/3/313.jpg
# FileNotFoundError ../data/images/31/4/314.jpg
# FileNotFoundError ../data/images/31/5/315.jpg
# FileNotFoundError ../data/images/31/6/316.jpg
# FileNotFoundError ../data/images/31/7/317.jpg
# FileNotFoundError ../data/images/31/8/318.jpg
# FileNotFoundError ../data/images/31/9/319.jpg
# FileNotFoundError ../data/images/32/0/320.jpg
# FileNotFoundError ../data/images/32/1/321.jpg
# FileNotFoundError ../data/images/32/2/322.jpg
# FileNotFoundError ../data/images/32/3/323.jpg
# FileNotFoundError ../data/images/32/4/324.jpg
# FileNotFoundError ../data/images/32/5/325.jpg
# FileNotFoundError ../data/images/32/6/326.jpg
# FileNotFoundError ../data/images/32/7/327.jpg
# FileNotFoundError ../data/images/32/8/328.jpg
# FileNotFoundError ../data/images/32/9/329.jpg
# FileNotFoundError ../data/images/33/0/330.jpg
# FileNotFoundError ../data/images/33/1/331.jpg
# FileNotFoundError ../data/images/33/2/332.jpg
# FileNotFoundError ../data/images/33/3/333.jpg
# FileNotFoundError ../data/images/33/4/334.jpg
# FileNotFoundError ../data/images/33/5/335.jpg
# FileNotFoundError ../data/images/33/6/336.jpg
# FileNotFoundError ../data/images/33/7/337.jpg
# FileNotFoundError ../data/images/33/8/338.jpg
# FileNotFoundError ../data/images/33/9/339.jpg
# FileNotFoundError ../data/images/34/0/340.jpg
# FileNotFoundError ../data/images/34/1/341.jpg
# FileNotFoundError ../data/images/34/2/342.jpg
# FileNotFoundError ../data/images/34/3/343.jpg
# FileNotFoundError ../data/images/34/4/344.jpg
# FileNotFoundError ../data/images/34/5/345.jpg
# FileNotFoundError ../data/images/34/6/346.jpg
# FileNotFoundError ../data/images/34/7/347.jpg
# FileNotFoundError ../data/images/34/8/348.jpg
# FileNotFoundError ../data/images/34/9/349.jpg
# FileNotFoundError ../data/images/35/0/350.jpg
# FileNotFoundError ../data/images/35/1/351.jpg
# FileNotFoundError ../data/images/35/2/352.jpg
# FileNotFoundError ../data/images/35/3/353.jpg
# FileNotFoundError ../data/images/35/4/354.jpg
# FileNotFoundError ../data/images/35/5/355.jpg
# FileNotFoundError ../data/images/35/6/356.jpg
# FileNotFoundError ../data/images/35/7/357.jpg
# FileNotFoundError ../data/images/35/8/358.jpg
# FileNotFoundError ../data/images/35/9/359.jpg
# FileNotFoundError ../data/images/36/0/360.jpg
# FileNotFoundError ../data/images/36/1/361.jpg
# FileNotFoundError ../data/images/36/2/362.jpg
# FileNotFoundError ../data/images/36/3/363.jpg
# FileNotFoundError ../data/images/36/4/364.jpg
# FileNotFoundError ../data/images/36/5/365.jpg
# FileNotFoundError ../data/images/36/6/366.jpg
# FileNotFoundError ../data/images/36/7/367.jpg
# FileNotFoundError ../data/images/36/8/368.jpg
# FileNotFoundError ../data/images/36/9/369.jpg
# FileNotFoundError ../data/images/37/0/370.jpg
# FileNotFoundError ../data/images/37/1/371.jpg
# FileNotFoundError ../data/images/37/2/372.jpg
# FileNotFoundError ../data/images/37/3/373.jpg
# FileNotFoundError ../data/images/37/4/374.jpg
# FileNotFoundError ../data/images/37/5/375.jpg
# FileNotFoundError ../data/images/37/6/376.jpg
# FileNotFoundError ../data/images/37/7/377.jpg
# FileNotFoundError ../data/images/37/8/378.jpg
# FileNotFoundError ../data/images/37/9/379.jpg
# FileNotFoundError ../data/images/38/0/380.jpg
# FileNotFoundError ../data/images/38/1/381.jpg
# FileNotFoundError ../data/images/38/2/382.jpg
# FileNotFoundError ../data/images/38/3/383.jpg
# FileNotFoundError ../data/images/38/4/384.jpg
# FileNotFoundError ../data/images/38/5/385.jpg
# FileNotFoundError ../data/images/38/6/386.jpg
# FileNotFoundError ../data/images/38/7/387.jpg
# FileNotFoundError ../data/images/38/8/388.jpg
# FileNotFoundError ../data/images/38/9/389.jpg
# FileNotFoundError ../data/images/39/0/390.jpg
# FileNotFoundError ../data/images/39/1/391.jpg
# FileNotFoundError ../data/images/39/2/392.jpg
# FileNotFoundError ../data/images/39/3/393.jpg
# FileNotFoundError ../data/images/39/4/394.jpg
# FileNotFoundError ../data/images/39/5/395.jpg
# FileNotFoundError ../data/images/39/6/396.jpg
# FileNotFoundError ../data/images/39/7/397.jpg
# FileNotFoundError ../data/images/39/8/398.jpg
# FileNotFoundError ../data/images/39/9/399.jpg
# FileNotFoundError ../data/images/40/0/400.jpg
# FileNotFoundError ../data/images/40/1/401.jpg
# FileNotFoundError ../data/images/40/2/402.jpg
# FileNotFoundError ../data/images/40/3/403.jpg
# FileNotFoundError ../data/images/40/4/404.jpg
# FileNotFoundError ../data/images/40/5/405.jpg
# FileNotFoundError ../data/images/40/6/406.jpg
# FileNotFoundError ../data/images/40/7/407.jpg
# FileNotFoundError ../data/images/40/8/408.jpg
# FileNotFoundError ../data/images/40/9/409.jpg
# FileNotFoundError ../data/images/41/0/410.jpg
# FileNotFoundError ../data/images/41/1/411.jpg
# FileNotFoundError ../data/images/41/2/412.jpg
# FileNotFoundError ../data/images/41/3/413.jpg
# FileNotFoundError ../data/images/41/4/414.jpg
# FileNotFoundError ../data/images/41/5/415.jpg
# FileNotFoundError ../data/images/41/6/416.jpg
# FileNotFoundError ../data/images/41/7/417.jpg
# FileNotFoundError ../data/images/41/8/418.jpg
# FileNotFoundError ../data/images/41/9/419.jpg
# FileNotFoundError ../data/images/42/0/420.jpg
# FileNotFoundError ../data/images/42/1/421.jpg
# FileNotFoundError ../data/images/42/2/422.jpg
# FileNotFoundError ../data/images/42/3/423.jpg
# FileNotFoundError ../data/images/42/4/424.jpg
# FileNotFoundError ../data/images/42/5/425.jpg
# FileNotFoundError ../data/images/42/6/426.jpg
# FileNotFoundError ../data/images/42/7/427.jpg
# FileNotFoundError ../data/images/42/8/428.jpg
# FileNotFoundError ../data/images/42/9/429.jpg
# FileNotFoundError ../data/images/43/0/430.jpg
# FileNotFoundError ../data/images/43/1/431.jpg
# FileNotFoundError ../data/images/43/2/432.jpg
# FileNotFoundError ../data/images/43/3/433.jpg
# FileNotFoundError ../data/images/43/4/434.jpg
# FileNotFoundError ../data/images/43/5/435.jpg
# FileNotFoundError ../data/images/43/6/436.jpg
# FileNotFoundError ../data/images/43/7/437.jpg
# FileNotFoundError ../data/images/43/8/438.jpg
# FileNotFoundError ../data/images/43/9/439.jpg
# FileNotFoundError ../data/images/44/0/440.jpg
# FileNotFoundError ../data/images/44/1/441.jpg
# FileNotFoundError ../data/images/44/2/442.jpg
# FileNotFoundError ../data/images/44/3/443.jpg
# FileNotFoundError ../data/images/44/4/444.jpg
# FileNotFoundError ../data/images/44/5/445.jpg
# FileNotFoundError ../data/images/44/6/446.jpg
# FileNotFoundError ../data/images/44/7/447.jpg
# FileNotFoundError ../data/images/44/8/448.jpg
# FileNotFoundError ../data/images/44/9/449.jpg
# FileNotFoundError ../data/images/45/0/450.jpg
# FileNotFoundError ../data/images/45/1/451.jpg
# FileNotFoundError ../data/images/45/2/452.jpg
# FileNotFoundError ../data/images/45/3/453.jpg
# FileNotFoundError ../data/images/45/4/454.jpg
# FileNotFoundError ../data/images/45/5/455.jpg
# FileNotFoundError ../data/images/45/6/456.jpg
# FileNotFoundError ../data/images/45/7/457.jpg
# FileNotFoundError ../data/images/45/8/458.jpg
# FileNotFoundError ../data/images/45/9/459.jpg
# FileNotFoundError ../data/images/46/0/460.jpg
# FileNotFoundError ../data/images/46/1/461.jpg
# FileNotFoundError ../data/images/46/2/462.jpg
# FileNotFoundError ../data/images/46/3/463.jpg
# FileNotFoundError ../data/images/46/4/464.jpg
# FileNotFoundError ../data/images/46/5/465.jpg
# FileNotFoundError ../data/images/46/6/466.jpg
# FileNotFoundError ../data/images/46/7/467.jpg
# FileNotFoundError ../data/images/46/8/468.jpg
# FileNotFoundError ../data/images/46/9/469.jpg
# FileNotFoundError ../data/images/47/0/470.jpg
# FileNotFoundError ../data/images/47/1/471.jpg
# FileNotFoundError ../data/images/47/2/472.jpg
# FileNotFoundError ../data/images/47/3/473.jpg
# FileNotFoundError ../data/images/47/4/474.jpg
# FileNotFoundError ../data/images/47/5/475.jpg
# FileNotFoundError ../data/images/47/6/476.jpg
# FileNotFoundError ../data/images/47/7/477.jpg
# FileNotFoundError ../data/images/47/8/478.jpg
# FileNotFoundError ../data/images/47/9/479.jpg
# FileNotFoundError ../data/images/48/0/480.jpg
# FileNotFoundError ../data/images/48/1/481.jpg
# FileNotFoundError ../data/images/48/2/482.jpg
# FileNotFoundError ../data/images/48/3/483.jpg
# FileNotFoundError ../data/images/48/4/484.jpg
# FileNotFoundError ../data/images/48/5/485.jpg
# FileNotFoundError ../data/images/48/6/486.jpg
# FileNotFoundError ../data/images/48/7/487.jpg
# FileNotFoundError ../data/images/48/9/489.jpg
# FileNotFoundError ../data/images/49/0/490.jpg
# FileNotFoundError ../data/images/49/1/491.jpg
# FileNotFoundError ../data/images/49/2/492.jpg
# FileNotFoundError ../data/images/49/3/493.jpg
# FileNotFoundError ../data/images/49/4/494.jpg
# FileNotFoundError ../data/images/49/5/495.jpg
# FileNotFoundError ../data/images/49/6/496.jpg
# FileNotFoundError ../data/images/49/7/497.jpg
# FileNotFoundError ../data/images/49/8/498.jpg
# FileNotFoundError ../data/images/49/9/499.jpg
# FileNotFoundError ../data/images/50/0/500.jpg
# FileNotFoundError ../data/images/50/1/501.jpg
# FileNotFoundError ../data/images/50/2/502.jpg
# FileNotFoundError ../data/images/50/3/503.jpg
# FileNotFoundError ../data/images/50/4/504.jpg
# FileNotFoundError ../data/images/50/5/505.jpg
# FileNotFoundError ../data/images/50/6/506.jpg
# FileNotFoundError ../data/images/50/7/507.jpg
# FileNotFoundError ../data/images/50/8/508.jpg
# FileNotFoundError ../data/images/50/9/509.jpg
# FileNotFoundError ../data/images/51/0/510.jpg
# FileNotFoundError ../data/images/51/1/511.jpg
# FileNotFoundError ../data/images/51/2/512.jpg
# FileNotFoundError ../data/images/51/3/513.jpg
# FileNotFoundError ../data/images/51/4/514.jpg
# FileNotFoundError ../data/images/51/5/515.jpg
# FileNotFoundError ../data/images/51/6/516.jpg
# FileNotFoundError ../data/images/51/7/517.jpg
# FileNotFoundError ../data/images/51/8/518.jpg
# FileNotFoundError ../data/images/51/9/519.jpg
# FileNotFoundError ../data/images/52/0/520.jpg
# FileNotFoundError ../data/images/52/1/521.jpg
# FileNotFoundError ../data/images/52/2/522.jpg
# FileNotFoundError ../data/images/52/3/523.jpg
# FileNotFoundError ../data/images/52/4/524.jpg
# FileNotFoundError ../data/images/52/5/525.jpg
# FileNotFoundError ../data/images/52/6/526.jpg
# FileNotFoundError ../data/images/52/7/527.jpg
# FileNotFoundError ../data/images/52/8/528.jpg
# FileNotFoundError ../data/images/52/9/529.jpg
# FileNotFoundError ../data/images/53/0/530.jpg
# FileNotFoundError ../data/images/53/1/531.jpg
# FileNotFoundError ../data/images/53/2/532.jpg
# FileNotFoundError ../data/images/53/3/533.jpg
# FileNotFoundError ../data/images/53/4/534.jpg
# FileNotFoundError ../data/images/53/5/535.jpg
# FileNotFoundError ../data/images/53/6/536.jpg
# FileNotFoundError ../data/images/53/7/537.jpg
# FileNotFoundError ../data/images/53/8/538.jpg
# FileNotFoundError ../data/images/53/9/539.jpg
# FileNotFoundError ../data/images/54/0/540.jpg
# FileNotFoundError ../data/images/54/1/541.jpg
# FileNotFoundError ../data/images/54/2/542.jpg
# FileNotFoundError ../data/images/54/3/543.jpg
# FileNotFoundError ../data/images/54/4/544.jpg
# FileNotFoundError ../data/images/54/5/545.jpg
# FileNotFoundError ../data/images/54/6/546.jpg
# FileNotFoundError ../data/images/54/7/547.jpg
# FileNotFoundError ../data/images/54/8/548.jpg
# FileNotFoundError ../data/images/54/9/549.jpg
# FileNotFoundError ../data/images/55/0/550.jpg
# FileNotFoundError ../data/images/55/1/551.jpg
# FileNotFoundError ../data/images/55/2/552.jpg
# FileNotFoundError ../data/images/55/3/553.jpg
# FileNotFoundError ../data/images/55/4/554.jpg
# FileNotFoundError ../data/images/55/5/555.jpg
# FileNotFoundError ../data/images/55/6/556.jpg
# FileNotFoundError ../data/images/55/7/557.jpg
# FileNotFoundError ../data/images/55/8/558.jpg
# FileNotFoundError ../data/images/55/9/559.jpg
# FileNotFoundError ../data/images/56/0/560.jpg
# FileNotFoundError ../data/images/56/1/561.jpg
# FileNotFoundError ../data/images/56/2/562.jpg
# FileNotFoundError ../data/images/56/3/563.jpg
# FileNotFoundError ../data/images/56/4/564.jpg
# FileNotFoundError ../data/images/56/5/565.jpg
# FileNotFoundError ../data/images/56/6/566.jpg
# FileNotFoundError ../data/images/56/7/567.jpg
# FileNotFoundError ../data/images/56/8/568.jpg
# FileNotFoundError ../data/images/56/9/569.jpg
# FileNotFoundError ../data/images/57/0/570.jpg
# FileNotFoundError ../data/images/57/1/571.jpg
# FileNotFoundError ../data/images/57/2/572.jpg
# FileNotFoundError ../data/images/57/3/573.jpg
# FileNotFoundError ../data/images/57/4/574.jpg
# FileNotFoundError ../data/images/57/5/575.jpg
# FileNotFoundError ../data/images/57/6/576.jpg
# FileNotFoundError ../data/images/57/7/577.jpg
# FileNotFoundError ../data/images/57/8/578.jpg
# FileNotFoundError ../data/images/57/9/579.jpg
# FileNotFoundError ../data/images/58/0/580.jpg
# FileNotFoundError ../data/images/58/1/581.jpg
# FileNotFoundError ../data/images/58/2/582.jpg
# FileNotFoundError ../data/images/58/3/583.jpg
# FileNotFoundError ../data/images/58/4/584.jpg
# FileNotFoundError ../data/images/58/5/585.jpg
# FileNotFoundError ../data/images/58/6/586.jpg
# FileNotFoundError ../data/images/58/7/587.jpg
# FileNotFoundError ../data/images/58/8/588.jpg
# FileNotFoundError ../data/images/58/9/589.jpg
# FileNotFoundError ../data/images/59/0/590.jpg
# FileNotFoundError ../data/images/59/1/591.jpg
# FileNotFoundError ../data/images/59/2/592.jpg
# FileNotFoundError ../data/images/59/3/593.jpg
# FileNotFoundError ../data/images/59/4/594.jpg
# FileNotFoundError ../data/images/59/5/595.jpg
# FileNotFoundError ../data/images/59/6/596.jpg
# FileNotFoundError ../data/images/59/7/597.jpg
# FileNotFoundError ../data/images/59/8/598.jpg
# FileNotFoundError ../data/images/60/0/600.jpg
# FileNotFoundError ../data/images/60/1/601.jpg
# FileNotFoundError ../data/images/60/2/602.jpg
# FileNotFoundError ../data/images/60/3/603.jpg
# FileNotFoundError ../data/images/60/4/604.jpg
# FileNotFoundError ../data/images/60/5/605.jpg
# FileNotFoundError ../data/images/60/6/606.jpg
# FileNotFoundError ../data/images/60/7/607.jpg
# FileNotFoundError ../data/images/60/8/608.jpg
# FileNotFoundError ../data/images/60/9/609.jpg
# FileNotFoundError ../data/images/61/0/610.jpg
# FileNotFoundError ../data/images/61/1/611.jpg
# FileNotFoundError ../data/images/61/2/612.jpg
# FileNotFoundError ../data/images/61/3/613.jpg
# FileNotFoundError ../data/images/61/4/614.jpg
# FileNotFoundError ../data/images/61/5/615.jpg
# FileNotFoundError ../data/images/61/6/616.jpg
# FileNotFoundError ../data/images/61/7/617.jpg
# FileNotFoundError ../data/images/61/8/618.jpg
# FileNotFoundError ../data/images/61/9/619.jpg
# FileNotFoundError ../data/images/62/0/620.jpg
# FileNotFoundError ../data/images/62/1/621.jpg
# FileNotFoundError ../data/images/62/2/622.jpg
# FileNotFoundError ../data/images/62/3/623.jpg
# FileNotFoundError ../data/images/62/4/624.jpg
# FileNotFoundError ../data/images/62/5/625.jpg
# FileNotFoundError ../data/images/62/6/626.jpg
# FileNotFoundError ../data/images/62/7/627.jpg
# FileNotFoundError ../data/images/62/8/628.jpg
# FileNotFoundError ../data/images/62/9/629.jpg
# FileNotFoundError ../data/images/63/0/630.jpg
# FileNotFoundError ../data/images/63/1/631.jpg
# FileNotFoundError ../data/images/63/2/632.jpg
# FileNotFoundError ../data/images/63/3/633.jpg
# FileNotFoundError ../data/images/63/4/634.jpg
# FileNotFoundError ../data/images/63/5/635.jpg
# FileNotFoundError ../data/images/63/6/636.jpg
# FileNotFoundError ../data/images/63/7/637.jpg
# FileNotFoundError ../data/images/63/8/638.jpg
# FileNotFoundError ../data/images/63/9/639.jpg
# FileNotFoundError ../data/images/64/0/640.jpg
# FileNotFoundError ../data/images/64/1/641.jpg
# FileNotFoundError ../data/images/64/2/642.jpg
# FileNotFoundError ../data/images/64/3/643.jpg
# FileNotFoundError ../data/images/64/4/644.jpg
# FileNotFoundError ../data/images/64/5/645.jpg
# FileNotFoundError ../data/images/64/6/646.jpg
# FileNotFoundError ../data/images/64/7/647.jpg
# FileNotFoundError ../data/images/64/8/648.jpg
# FileNotFoundError ../data/images/64/9/649.jpg
# FileNotFoundError ../data/images/65/0/650.jpg
# FileNotFoundError ../data/images/65/1/651.jpg
# FileNotFoundError ../data/images/65/2/652.jpg
# FileNotFoundError ../data/images/65/3/653.jpg
# FileNotFoundError ../data/images/65/4/654.jpg
# FileNotFoundError ../data/images/65/5/655.jpg
# FileNotFoundError ../data/images/65/6/656.jpg
# FileNotFoundError ../data/images/65/7/657.jpg
# FileNotFoundError ../data/images/65/8/658.jpg
# FileNotFoundError ../data/images/65/9/659.jpg
# FileNotFoundError ../data/images/66/0/660.jpg
# FileNotFoundError ../data/images/66/1/661.jpg
# FileNotFoundError ../data/images/66/2/662.jpg
# FileNotFoundError ../data/images/66/3/663.jpg
# FileNotFoundError ../data/images/66/4/664.jpg
# FileNotFoundError ../data/images/66/5/665.jpg
# FileNotFoundError ../data/images/66/6/666.jpg
# FileNotFoundError ../data/images/66/7/667.jpg
# FileNotFoundError ../data/images/66/8/668.jpg
# FileNotFoundError ../data/images/66/9/669.jpg
# FileNotFoundError ../data/images/67/0/670.jpg
# FileNotFoundError ../data/images/67/1/671.jpg
# FileNotFoundError ../data/images/67/2/672.jpg
# FileNotFoundError ../data/images/67/3/673.jpg
# FileNotFoundError ../data/images/67/4/674.jpg
# FileNotFoundError ../data/images/67/5/675.jpg
# FileNotFoundError ../data/images/67/6/676.jpg
# FileNotFoundError ../data/images/67/7/677.jpg
# FileNotFoundError ../data/images/67/8/678.jpg
# FileNotFoundError ../data/images/67/9/679.jpg
# FileNotFoundError ../data/images/68/0/680.jpg
# FileNotFoundError ../data/images/68/1/681.jpg
# FileNotFoundError ../data/images/68/2/682.jpg
# FileNotFoundError ../data/images/68/3/683.jpg
# FileNotFoundError ../data/images/68/4/684.jpg
# FileNotFoundError ../data/images/68/5/685.jpg
# FileNotFoundError ../data/images/68/6/686.jpg
# FileNotFoundError ../data/images/68/7/687.jpg
# FileNotFoundError ../data/images/68/8/688.jpg
# FileNotFoundError ../data/images/68/9/689.jpg
# FileNotFoundError ../data/images/69/0/690.jpg
# FileNotFoundError ../data/images/69/1/691.jpg
# FileNotFoundError ../data/images/69/2/692.jpg
# FileNotFoundError ../data/images/69/3/693.jpg
# FileNotFoundError ../data/images/69/4/694.jpg
# FileNotFoundError ../data/images/69/5/695.jpg
# FileNotFoundError ../data/images/69/6/696.jpg
# FileNotFoundError ../data/images/69/7/697.jpg
# FileNotFoundError ../data/images/69/8/698.jpg
# FileNotFoundError ../data/images/69/9/699.jpg
# FileNotFoundError ../data/images/70/0/700.jpg
# FileNotFoundError ../data/images/70/1/701.jpg
# FileNotFoundError ../data/images/70/2/702.jpg
# FileNotFoundError ../data/images/70/3/703.jpg
# FileNotFoundError ../data/images/70/4/704.jpg
# FileNotFoundError ../data/images/70/5/705.jpg
# FileNotFoundError ../data/images/70/6/706.jpg
# FileNotFoundError ../data/images/70/7/707.jpg
# FileNotFoundError ../data/images/70/8/708.jpg
# FileNotFoundError ../data/images/70/9/709.jpg
# FileNotFoundError ../data/images/71/0/710.jpg
# FileNotFoundError ../data/images/71/1/711.jpg
# FileNotFoundError ../data/images/71/2/712.jpg
# FileNotFoundError ../data/images/71/3/713.jpg
# FileNotFoundError ../data/images/71/4/714.jpg
# FileNotFoundError ../data/images/71/5/715.jpg
# FileNotFoundError ../data/images/71/6/716.jpg
# FileNotFoundError ../data/images/71/7/717.jpg
# FileNotFoundError ../data/images/71/8/718.jpg
# FileNotFoundError ../data/images/71/9/719.jpg
# FileNotFoundError ../data/images/72/0/720.jpg
# FileNotFoundError ../data/images/72/1/721.jpg
# FileNotFoundError ../data/images/72/2/722.jpg
# FileNotFoundError ../data/images/72/3/723.jpg
# FileNotFoundError ../data/images/72/4/724.jpg
# FileNotFoundError ../data/images/72/5/725.jpg
# FileNotFoundError ../data/images/72/6/726.jpg
# FileNotFoundError ../data/images/72/7/727.jpg
# FileNotFoundError ../data/images/72/8/728.jpg
# FileNotFoundError ../data/images/72/9/729.jpg
# FileNotFoundError ../data/images/73/0/730.jpg
# FileNotFoundError ../data/images/73/1/731.jpg
# FileNotFoundError ../data/images/73/2/732.jpg
# FileNotFoundError ../data/images/73/3/733.jpg
# FileNotFoundError ../data/images/73/4/734.jpg
# FileNotFoundError ../data/images/73/5/735.jpg
# FileNotFoundError ../data/images/73/6/736.jpg
# FileNotFoundError ../data/images/73/7/737.jpg
# FileNotFoundError ../data/images/73/8/738.jpg
# FileNotFoundError ../data/images/73/9/739.jpg
# FileNotFoundError ../data/images/74/0/740.jpg
# FileNotFoundError ../data/images/74/1/741.jpg
# FileNotFoundError ../data/images/74/2/742.jpg
# FileNotFoundError ../data/images/74/3/743.jpg
# FileNotFoundError ../data/images/74/4/744.jpg
# FileNotFoundError ../data/images/74/5/745.jpg
# FileNotFoundError ../data/images/74/6/746.jpg
# FileNotFoundError ../data/images/74/7/747.jpg
# FileNotFoundError ../data/images/74/8/748.jpg
# FileNotFoundError ../data/images/74/9/749.jpg
# FileNotFoundError ../data/images/75/0/750.jpg
# FileNotFoundError ../data/images/75/1/751.jpg
# FileNotFoundError ../data/images/75/2/752.jpg
# FileNotFoundError ../data/images/75/3/753.jpg
# FileNotFoundError ../data/images/75/4/754.jpg
# FileNotFoundError ../data/images/75/5/755.jpg
# FileNotFoundError ../data/images/75/6/756.jpg
# FileNotFoundError ../data/images/75/7/757.jpg
# FileNotFoundError ../data/images/75/8/758.jpg
# FileNotFoundError ../data/images/75/9/759.jpg
# FileNotFoundError ../data/images/76/0/760.jpg
# FileNotFoundError ../data/images/76/1/761.jpg
# FileNotFoundError ../data/images/76/2/762.jpg
# FileNotFoundError ../data/images/76/3/763.jpg
# FileNotFoundError ../data/images/76/4/764.jpg
# FileNotFoundError ../data/images/76/5/765.jpg
# FileNotFoundError ../data/images/76/6/766.jpg
# FileNotFoundError ../data/images/76/7/767.jpg
# FileNotFoundError ../data/images/76/8/768.jpg
# FileNotFoundError ../data/images/76/9/769.jpg
# FileNotFoundError ../data/images/77/0/770.jpg
# FileNotFoundError ../data/images/77/1/771.jpg
# FileNotFoundError ../data/images/77/2/772.jpg
# FileNotFoundError ../data/images/77/3/773.jpg
# FileNotFoundError ../data/images/77/4/774.jpg
# FileNotFoundError ../data/images/77/5/775.jpg
# FileNotFoundError ../data/images/77/6/776.jpg
# FileNotFoundError ../data/images/77/7/777.jpg
# FileNotFoundError ../data/images/77/8/778.jpg
# FileNotFoundError ../data/images/77/9/779.jpg
# FileNotFoundError ../data/images/78/0/780.jpg
# FileNotFoundError ../data/images/78/1/781.jpg
# FileNotFoundError ../data/images/78/2/782.jpg
# FileNotFoundError ../data/images/78/3/783.jpg
# FileNotFoundError ../data/images/78/4/784.jpg
# FileNotFoundError ../data/images/78/5/785.jpg
# FileNotFoundError ../data/images/78/6/786.jpg
# FileNotFoundError ../data/images/78/7/787.jpg
# FileNotFoundError ../data/images/78/8/788.jpg
# FileNotFoundError ../data/images/78/9/789.jpg
# FileNotFoundError ../data/images/79/0/790.jpg
# FileNotFoundError ../data/images/79/1/791.jpg
# FileNotFoundError ../data/images/79/2/792.jpg
# FileNotFoundError ../data/images/79/3/793.jpg
# FileNotFoundError ../data/images/79/4/794.jpg
# FileNotFoundError ../data/images/79/5/795.jpg
# FileNotFoundError ../data/images/79/6/796.jpg
# FileNotFoundError ../data/images/79/7/797.jpg
# FileNotFoundError ../data/images/79/8/798.jpg
# FileNotFoundError ../data/images/79/9/799.jpg
# FileNotFoundError ../data/images/80/0/800.jpg
# FileNotFoundError ../data/images/80/1/801.jpg
# FileNotFoundError ../data/images/80/2/802.jpg
# FileNotFoundError ../data/images/80/3/803.jpg
# FileNotFoundError ../data/images/80/4/804.jpg
# FileNotFoundError ../data/images/80/5/805.jpg
# FileNotFoundError ../data/images/80/6/806.jpg
# FileNotFoundError ../data/images/80/7/807.jpg
# FileNotFoundError ../data/images/80/8/808.jpg
# FileNotFoundError ../data/images/80/9/809.jpg
# FileNotFoundError ../data/images/81/0/810.jpg
# FileNotFoundError ../data/images/81/1/811.jpg
# FileNotFoundError ../data/images/81/2/812.jpg
# FileNotFoundError ../data/images/81/3/813.jpg
# FileNotFoundError ../data/images/81/4/814.jpg
# FileNotFoundError ../data/images/81/5/815.jpg
# FileNotFoundError ../data/images/81/6/816.jpg
# FileNotFoundError ../data/images/81/7/817.jpg
# FileNotFoundError ../data/images/81/8/818.jpg
# FileNotFoundError ../data/images/81/9/819.jpg
# FileNotFoundError ../data/images/82/0/820.jpg
# FileNotFoundError ../data/images/82/1/821.jpg
# FileNotFoundError ../data/images/82/2/822.jpg
# FileNotFoundError ../data/images/82/3/823.jpg
# FileNotFoundError ../data/images/82/4/824.jpg
# FileNotFoundError ../data/images/82/5/825.jpg
# FileNotFoundError ../data/images/82/6/826.jpg
# FileNotFoundError ../data/images/82/7/827.jpg
# FileNotFoundError ../data/images/82/8/828.jpg
# FileNotFoundError ../data/images/82/9/829.jpg
# FileNotFoundError ../data/images/83/0/830.jpg
# FileNotFoundError ../data/images/83/1/831.jpg
# FileNotFoundError ../data/images/83/2/832.jpg
# FileNotFoundError ../data/images/83/3/833.jpg
# FileNotFoundError ../data/images/83/4/834.jpg
# FileNotFoundError ../data/images/83/5/835.jpg
# FileNotFoundError ../data/images/83/6/836.jpg
# FileNotFoundError ../data/images/83/7/837.jpg
# FileNotFoundError ../data/images/83/8/838.jpg
# FileNotFoundError ../data/images/83/9/839.jpg
# FileNotFoundError ../data/images/84/0/840.jpg
# FileNotFoundError ../data/images/84/1/841.jpg
# FileNotFoundError ../data/images/84/2/842.jpg
# FileNotFoundError ../data/images/84/3/843.jpg
# FileNotFoundError ../data/images/84/4/844.jpg
# FileNotFoundError ../data/images/84/5/845.jpg
# FileNotFoundError ../data/images/84/6/846.jpg
# FileNotFoundError ../data/images/84/7/847.jpg
# FileNotFoundError ../data/images/84/8/848.jpg
# FileNotFoundError ../data/images/84/9/849.jpg
# FileNotFoundError ../data/images/85/0/850.jpg
# FileNotFoundError ../data/images/85/1/851.jpg
# FileNotFoundError ../data/images/85/2/852.jpg
# FileNotFoundError ../data/images/85/3/853.jpg
# FileNotFoundError ../data/images/85/4/854.jpg
# FileNotFoundError ../data/images/85/5/855.jpg
# FileNotFoundError ../data/images/85/6/856.jpg
# FileNotFoundError ../data/images/85/7/857.jpg
# FileNotFoundError ../data/images/85/8/858.jpg
# FileNotFoundError ../data/images/85/9/859.jpg
# FileNotFoundError ../data/images/86/0/860.jpg
# FileNotFoundError ../data/images/86/1/861.jpg
# FileNotFoundError ../data/images/86/2/862.jpg
# FileNotFoundError ../data/images/86/3/863.jpg
# FileNotFoundError ../data/images/86/4/864.jpg
# FileNotFoundError ../data/images/86/5/865.jpg
# FileNotFoundError ../data/images/86/6/866.jpg
# FileNotFoundError ../data/images/86/7/867.jpg
# FileNotFoundError ../data/images/86/8/868.jpg
# FileNotFoundError ../data/images/86/9/869.jpg
# FileNotFoundError ../data/images/87/0/870.jpg
# FileNotFoundError ../data/images/87/1/871.jpg
# FileNotFoundError ../data/images/87/2/872.jpg
# FileNotFoundError ../data/images/87/3/873.jpg
# FileNotFoundError ../data/images/87/4/874.jpg
# FileNotFoundError ../data/images/87/5/875.jpg
# FileNotFoundError ../data/images/87/6/876.jpg
# FileNotFoundError ../data/images/87/7/877.jpg
# FileNotFoundError ../data/images/87/8/878.jpg
# FileNotFoundError ../data/images/87/9/879.jpg
# FileNotFoundError ../data/images/88/0/880.jpg
# FileNotFoundError ../data/images/88/1/881.jpg
# FileNotFoundError ../data/images/88/2/882.jpg
# FileNotFoundError ../data/images/88/3/883.jpg
# FileNotFoundError ../data/images/88/4/884.jpg
# FileNotFoundError ../data/images/88/5/885.jpg
# FileNotFoundError ../data/images/88/6/886.jpg
# FileNotFoundError ../data/images/88/7/887.jpg
# FileNotFoundError ../data/images/88/8/888.jpg
# FileNotFoundError ../data/images/88/9/889.jpg
# FileNotFoundError ../data/images/89/0/890.jpg
# FileNotFoundError ../data/images/89/1/891.jpg
# FileNotFoundError ../data/images/89/2/892.jpg
# FileNotFoundError ../data/images/89/3/893.jpg
# FileNotFoundError ../data/images/89/4/894.jpg
# FileNotFoundError ../data/images/89/5/895.jpg
# FileNotFoundError ../data/images/89/6/896.jpg
# FileNotFoundError ../data/images/89/7/897.jpg
# FileNotFoundError ../data/images/89/8/898.jpg
# FileNotFoundError ../data/images/89/9/899.jpg
# FileNotFoundError ../data/images/90/0/900.jpg
# FileNotFoundError ../data/images/90/1/901.jpg
# FileNotFoundError ../data/images/90/2/902.jpg
# FileNotFoundError ../data/images/90/3/903.jpg
# FileNotFoundError ../data/images/90/4/904.jpg
# FileNotFoundError ../data/images/90/5/905.jpg
# FileNotFoundError ../data/images/90/6/906.jpg
# FileNotFoundError ../data/images/90/7/907.jpg
# FileNotFoundError ../data/images/90/8/908.jpg
# FileNotFoundError ../data/images/90/9/909.jpg
# FileNotFoundError ../data/images/91/0/910.jpg
# FileNotFoundError ../data/images/91/1/911.jpg
# FileNotFoundError ../data/images/91/2/912.jpg
# FileNotFoundError ../data/images/91/3/913.jpg
# FileNotFoundError ../data/images/91/4/914.jpg
# FileNotFoundError ../data/images/91/5/915.jpg
# FileNotFoundError ../data/images/91/6/916.jpg
# FileNotFoundError ../data/images/91/7/917.jpg
# FileNotFoundError ../data/images/91/8/918.jpg
# FileNotFoundError ../data/images/91/9/919.jpg
# FileNotFoundError ../data/images/92/0/920.jpg
# FileNotFoundError ../data/images/92/1/921.jpg
# FileNotFoundError ../data/images/92/2/922.jpg
# FileNotFoundError ../data/images/92/3/923.jpg
# FileNotFoundError ../data/images/92/4/924.jpg
# FileNotFoundError ../data/images/92/5/925.jpg
# FileNotFoundError ../data/images/92/6/926.jpg
# FileNotFoundError ../data/images/92/8/928.jpg
# FileNotFoundError ../data/images/92/9/929.jpg
# FileNotFoundError ../data/images/93/0/930.jpg
# FileNotFoundError ../data/images/93/1/931.jpg
# FileNotFoundError ../data/images/93/2/932.jpg
# FileNotFoundError ../data/images/93/3/933.jpg
# FileNotFoundError ../data/images/93/4/934.jpg
# FileNotFoundError ../data/images/93/5/935.jpg
# FileNotFoundError ../data/images/93/6/936.jpg
# FileNotFoundError ../data/images/93/7/937.jpg
# FileNotFoundError ../data/images/93/8/938.jpg
# FileNotFoundError ../data/images/93/9/939.jpg
# FileNotFoundError ../data/images/94/0/940.jpg
# FileNotFoundError ../data/images/94/1/941.jpg
# FileNotFoundError ../data/images/94/2/942.jpg
# FileNotFoundError ../data/images/94/3/943.jpg
# FileNotFoundError ../data/images/94/4/944.jpg
# FileNotFoundError ../data/images/94/5/945.jpg
# FileNotFoundError ../data/images/94/6/946.jpg
# FileNotFoundError ../data/images/94/7/947.jpg
# FileNotFoundError ../data/images/94/8/948.jpg
# FileNotFoundError ../data/images/94/9/949.jpg
# FileNotFoundError ../data/images/95/0/950.jpg
# FileNotFoundError ../data/images/95/1/951.jpg
# FileNotFoundError ../data/images/95/2/952.jpg
# FileNotFoundError ../data/images/95/3/953.jpg
# FileNotFoundError ../data/images/95/4/954.jpg
# FileNotFoundError ../data/images/95/5/955.jpg
# FileNotFoundError ../data/images/95/6/956.jpg
# FileNotFoundError ../data/images/95/7/957.jpg
# FileNotFoundError ../data/images/95/8/958.jpg
# FileNotFoundError ../data/images/95/9/959.jpg
# FileNotFoundError ../data/images/96/0/960.jpg
# FileNotFoundError ../data/images/96/1/961.jpg
# FileNotFoundError ../data/images/96/2/962.jpg
# FileNotFoundError ../data/images/96/3/963.jpg
# FileNotFoundError ../data/images/96/4/964.jpg
# FileNotFoundError ../data/images/96/5/965.jpg
# FileNotFoundError ../data/images/96/6/966.jpg
# FileNotFoundError ../data/images/96/7/967.jpg
# FileNotFoundError ../data/images/96/8/968.jpg
# FileNotFoundError ../data/images/96/9/969.jpg
# FileNotFoundError ../data/images/97/0/970.jpg
# FileNotFoundError ../data/images/97/1/971.jpg
# FileNotFoundError ../data/images/97/2/972.jpg
# FileNotFoundError ../data/images/97/3/973.jpg
# FileNotFoundError ../data/images/97/4/974.jpg
# FileNotFoundError ../data/images/97/5/975.jpg
# FileNotFoundError ../data/images/97/6/976.jpg
# FileNotFoundError ../data/images/97/7/977.jpg
# FileNotFoundError ../data/images/97/8/978.jpg
# FileNotFoundError ../data/images/97/9/979.jpg
# FileNotFoundError ../data/images/98/0/980.jpg
# FileNotFoundError ../data/images/98/1/981.jpg
# FileNotFoundError ../data/images/98/2/982.jpg
# FileNotFoundError ../data/images/98/3/983.jpg
# FileNotFoundError ../data/images/98/4/984.jpg
# FileNotFoundError ../data/images/98/5/985.jpg
# FileNotFoundError ../data/images/98/6/986.jpg
# FileNotFoundError ../data/images/98/7/987.jpg
# FileNotFoundError ../data/images/98/8/988.jpg
# FileNotFoundError ../data/images/98/9/989.jpg
# FileNotFoundError ../data/images/99/0/990.jpg
# FileNotFoundError ../data/images/99/1/991.jpg
# FileNotFoundError ../data/images/99/2/992.jpg
# FileNotFoundError ../data/images/99/3/993.jpg
# FileNotFoundError ../data/images/99/4/994.jpg
# FileNotFoundError ../data/images/99/5/995.jpg
# FileNotFoundError ../data/images/99/6/996.jpg
# FileNotFoundError ../data/images/99/7/997.jpg
# FileNotFoundError ../data/images/99/8/998.jpg

# %%
embeddings.head()
# Out:
#    embedding_0  embedding_1  embedding_2  embedding_3  embedding_4  \
# 0     0.000000     0.394525     0.050905     0.127024     0.000000
# 1     0.007891     0.242910     0.028251     0.015308     0.342107
# 2     0.000000     0.138877     0.039775     0.026529     0.000000
# 3     0.278602     1.582474     0.040108     0.604458     0.293284
#
#    embedding_5  embedding_6  embedding_7  embedding_8  embedding_9  ...  \
# 0     0.000000     0.422399     0.496537     0.000000     0.000000  ...
# 1     0.787701     1.069703     0.357700     0.000000     0.004031  ...
# 2     0.205778     0.572292     1.575165     0.012644     0.082656  ...
# 3     0.062030     0.533228     0.000668     0.111376     0.011370  ...
#
#    embedding_2039  embedding_2040  embedding_2041  embedding_2042  \
# 0        0.003527        0.469738        0.000000        0.175133
# 1        0.039697        0.414626        0.000000        0.003298
# 2        0.118607        1.400151        0.031379        0.423990
# 3        1.048824        0.000000        0.000000        0.028882
#
#    embedding_2043  embedding_2044  embedding_2045  embedding_2046  \
# 0        0.749388        0.543183        0.000000        0.000000
# 1        0.276602        0.192753        0.013603        0.010138
# 2        0.585092        0.846554        0.264949        0.097781
# 3        0.000000        0.038599        0.006738        1.082916
#
#    embedding_2047  product_id
# 0        0.252123         277
# 1        0.708869         488
# 2        0.305391         599
# 3        0.987023         927
#
# [4 rows x 2049 columns]

# %%
import time

unique_name = int(time.time())
embeddings.to_parquet(f"../data/image_embeddings_{unique_name}.parquet")
